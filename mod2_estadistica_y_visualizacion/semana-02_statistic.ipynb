# %% [markdown]
# - Modulo 2 : Estadistica y Visualizacion de Datos
# - Sesion : 02
# - Fecha : 08/11/2025

# %%
import pandas as pd
import numpy as np

# %%
listado_docentes = {
    "0001": {
        "nombres": "Ana Maria",
        "apellidos": "Lopez Garcia",
        "edad": 34
    },
    "0002": {
        "nombres": "Juan Carlos",
        "apellidos": "Perez Soto",
        "edad": 45
        }
    }

print(listado_docentes["0002"])
# Out:
# {'nombres': 'Juan Carlos', 'apellidos': 'Perez Soto', 'edad': 45}

# %%
df = pd.DataFrame(listado_docentes)
print(df)
# Out:
#                    0001         0002
# nombres       Ana Maria  Juan Carlos
# apellidos  Lopez Garcia   Perez Soto
# edad                 34           45

# %%
df[["0001"]]
# Out:
#                    0001
# nombres       Ana Maria
# apellidos  Lopez Garcia
# edad                 34

# %%
df.head()
# Out:
#                    0001         0002
# nombres       Ana Maria  Juan Carlos
# apellidos  Lopez Garcia   Perez Soto
# edad                 34           45

# %%
df["0003"] =  df["0002"]

# %%
df.head()
# Out:
#                    0001         0002         0003
# nombres       Ana Maria  Juan Carlos  Juan Carlos
# apellidos  Lopez Garcia   Perez Soto   Perez Soto
# edad                 34           45           45

# %%
df["0004"] =  df["0003"] +df["0002"]

df.head()
# Out:
#                    0001         0002         0003                    0004
# nombres       Ana Maria  Juan Carlos  Juan Carlos  Juan CarlosJuan Carlos
# apellidos  Lopez Garcia   Perez Soto   Perez Soto    Perez SotoPerez Soto
# edad                 34           45           45                      90

# %%
df.insert(1, "1111", df["0003"] )
df.head()
# Out:
#                    0001         1111         0002         0003  \
# nombres       Ana Maria  Juan Carlos  Juan Carlos  Juan Carlos
# apellidos  Lopez Garcia   Perez Soto   Perez Soto   Perez Soto
# edad                 34           45           45           45
#
#                              0004
# nombres    Juan CarlosJuan Carlos
# apellidos    Perez SotoPerez Soto
# edad                           90

# %%
df = df.assign( nuevo = ["Jose","Rubio",34])

# %%
df.head()
# Out:
#                    0001         1111         0002         0003  \
# nombres       Ana Maria  Juan Carlos  Juan Carlos  Juan Carlos
# apellidos  Lopez Garcia   Perez Soto   Perez Soto   Perez Soto
# edad                 34           45           45           45
#
#                              0004  nuevo
# nombres    Juan CarlosJuan Carlos   Jose
# apellidos    Perez SotoPerez Soto  Rubio
# edad                           90     34

# %% [markdown]
# ## Series con Pandas

# %%
nro_list = [10,20,40,60,80]
serie_pd = pd.Series(nro_list)
print(serie_pd)
# Out:
# 0    10
# 1    20
# 2    40
# 3    60
# 4    80
# dtype: int64

# %%
mi_listado = [x for x in range(2,101,2)]
serie_pares = pd.Series(mi_listado)
serie_pares
# Out:
# 0       2
# 1       4
# 2       6
# 3       8
# 4      10
# 5      12
# 6      14
# 7      16
# 8      18
# 9      20
# 10     22
# 11     24
# 12     26
# 13     28
# 14     30
# 15     32
# 16     34
# 17     36
# 18     38
# 19     40
# 20     42
# 21     44
# 22     46
# 23     48
# 24     50
# 25     52
# 26     54
# 27     56
# 28     58
# 29     60
# 30     62
# 31     64
# 32     66
# 33     68
# 34     70
# 35     72
# 36     74
# 37     76
# 38     78
# 39     80
# 40     82
# 41     84
# 42     86
# 43     88
# 44     90
# 45     92
# 46     94
# 47     96
# 48     98
# 49    100
# dtype: int64
