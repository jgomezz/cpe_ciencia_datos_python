# %% [markdown]
# # Análisis de Datos con Python

# %% [markdown]
# <h2>Indice</h2>
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
# <ol>
#     <li><a href="#import_data">Importar datos de la sesión 01</a></li>
#     <li><a href="#pattern_visualization">Analizando individualmente las variables usando visualización</a></li>
#     <li><a href="#discriptive_statistics">Análisis Estadístico Descriptivo</a></li>
#     <li><a href="#basic_grouping">Usando métodos de agrupación</a></li>
#     <li><a href="#correlation_causation">Correlación y Causalidad</a></li>
#     <li><a href="#anova">ANOVA</a></li>
# </ol>
# </div>
#
# <hr>

# %% [markdown]
# <h2>¿Cuál es la principal caracteristica que tiene el mayor impacto en el precio del auto?</h2>

# %% [markdown]
# <h2 id="import_data">1. Importar datos de la sesión 01</h2>

# %% [markdown]
# <h4>Setup</h4>

# %% [markdown]
#  Import libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
#  load data and store in dataframe df:

# %%
namefile ='dataset/automobileEDA.csv'
df = pd.read_csv(namefile)
df.head()
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# 1  convertible          rwd           front        88.6  0.811148  ...
# 2    hatchback          rwd           front        94.5  0.822681  ...
# 3        sedan          fwd           front        99.8  0.848630  ...
# 4        sedan          4wd           front        99.4  0.848630  ...
#
#    compression-ratio  horsepower  peak-rpm city-mpg highway-mpg    price  \
# 0                9.0       111.0    5000.0       21          27  13495.0
# 1                9.0       111.0    5000.0       21          27  16500.0
# 2                9.0       154.0    5000.0       19          26  16500.0
# 3               10.0       102.0    5500.0       24          30  13950.0
# 4                8.0       115.0    5500.0       18          22  17450.0
#
#   city-L/100km  horsepower-binned  diesel  gas
# 0    11.190476             Medium       0    1
# 1    11.190476             Medium       0    1
# 2    12.368421             Medium       0    1
# 3     9.791667             Medium       0    1
# 4    13.055556             Medium       0    1
#
# [5 rows x 29 columns]

# %%
df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'aspiration', 'num-of-doors',
#        'body-style', 'drive-wheels', 'engine-location', 'wheel-base', 'length',
#        'width', 'height', 'curb-weight', 'engine-type', 'num-of-cylinders',
#        'engine-size', 'fuel-system', 'bore', 'stroke', 'compression-ratio',
#        'horsepower', 'peak-rpm', 'city-mpg', 'highway-mpg', 'price',
#        'city-L/100km', 'horsepower-binned', 'diesel', 'gas'],
#       dtype='object')

# %% [markdown]
# ## Descripción de las variables
#
# - 'symboling' : Nivel de riesgo del seguro , de menor riesgo (-3) a mayor riesgto (3)
# - "normalized-losses" : Es la perdida del pago promedio del seguro del auto por año y representa la perdida por año del auto. El valor oscila entre 65 a 256
# - 'make' : Marca
# - "aspiration" : Como el motor de combustión interno trabaja , puede ser estandar (std) o turbo
# - 'num-of-doors' : Número de puertas
# - "body-style" : Carroceria
# - 'drive-wheels' : Tracción de las ruedas
# - 'engine-location' : Localización del motor
# - 'wheel-base' : Distancia entre ejes
# - 'length' : Longitud
# - 'width' : Ancho
# - 'height': Alto
# - 'curb-weight' : Peso del auto con equipación completa
# - 'engine-type': Tipo de motor
# - 'num-of-cylinders' : Número de cilindros
# - 'engine-size' : Tamaño del motor
# - 'fuel-system' : Sistema de combustible
# - 'bore' : Diámetro
# - 'stroke' : Distancia recorrida por el pistón durante cada ciclo
# - 'compression-ratio': Ratio de comprensión
# - 'horsepower' : Caballos de potencia
# - 'horsepower-binned' : Caballos de potencia convertidos en una variable categórica
# - 'peak-rpm' : RPM pico
# - 'city-mpg' : consumo en la ciudad en millas por galon
# - 'highway-mpg' : consumo en autopista en millas por galon
# - 'price' : Precio
# - 'city-L/100km' :  consumo en la ciudad en litros por kilometro
# - 'diesel' : variable dummy para consumo por petróleo
# - 'gas': variable dummy para consumo por gasoina

# %%
df.describe()
# Out:
#         symboling  normalized-losses  wheel-base      length       width  \
# count  201.000000          201.00000  201.000000  201.000000  201.000000
# mean     0.840796          122.00000   98.797015    0.837102    0.915126
# std      1.254802           31.99625    6.066366    0.059213    0.029187
# min     -2.000000           65.00000   86.600000    0.678039    0.837500
# 25%      0.000000          101.00000   94.500000    0.801538    0.890278
# 50%      1.000000          122.00000   97.000000    0.832292    0.909722
# 75%      2.000000          137.00000  102.400000    0.881788    0.925000
# max      3.000000          256.00000  120.900000    1.000000    1.000000
#
#            height  curb-weight  engine-size        bore      stroke  \
# count  201.000000   201.000000   201.000000  201.000000  197.000000
# mean    53.766667  2555.666667   126.875622    3.330692    3.256904
# std      2.447822   517.296727    41.546834    0.268072    0.319256
# min     47.800000  1488.000000    61.000000    2.540000    2.070000
# 25%     52.000000  2169.000000    98.000000    3.150000    3.110000
# 50%     54.100000  2414.000000   120.000000    3.310000    3.290000
# 75%     55.500000  2926.000000   141.000000    3.580000    3.410000
# max     59.800000  4066.000000   326.000000    3.940000    4.170000
#
#        compression-ratio  horsepower     peak-rpm    city-mpg  highway-mpg  \
# count         201.000000  201.000000   201.000000  201.000000   201.000000
# mean           10.164279  103.405534  5117.665368   25.179104    30.686567
# std             4.004965   37.365700   478.113805    6.423220     6.815150
# min             7.000000   48.000000  4150.000000   13.000000    16.000000
# 25%             8.600000   70.000000  4800.000000   19.000000    25.000000
# 50%             9.000000   95.000000  5125.369458   24.000000    30.000000
# 75%             9.400000  116.000000  5500.000000   30.000000    34.000000
# max            23.000000  262.000000  6600.000000   49.000000    54.000000
#
#               price  city-L/100km      diesel         gas
# count    201.000000    201.000000  201.000000  201.000000
# mean   13207.129353      9.944145    0.099502    0.900498
# std     7947.066342      2.534599    0.300083    0.300083
# min     5118.000000      4.795918    0.000000    0.000000
# 25%     7775.000000      7.833333    0.000000    1.000000
# 50%    10295.000000      9.791667    0.000000    1.000000
# 75%    16500.000000     12.368421    0.000000    1.000000
# max    45400.000000     18.076923    1.000000    1.000000

# %% [markdown]
# <h2 id="pattern_visualization">2. Analizando individualmente las variables usando visualización</h2>

# %% [markdown]
# Importar las librerias "Matplotlib" y "Seaborn"

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# <h3>¿Como escoger el correcto método de visualización?</h3>
# <p>Identificamos los tipos de variables que tenemos.</p>

# %%
# lista os tipos de datos de cada variable predictora
df.dtypes
# Out:
# symboling              int64
# normalized-losses      int64
# make                  object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# city-L/100km         float64
# horsepower-binned     object
# diesel                 int64
# gas                    int64
# dtype: object

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <h3>Pregunta #1:</h3>
#
# <b>¿Qué tipo de datos tiene la variable  "peak-rpm"? </b>
# </div>

# %% [markdown]
# Se calcula las correlaciones entre las variables del tipo "int64" o "float64" usando el metodo "corr":

# %%
df.corr(numeric_only=True)
# Out:
#                    symboling  normalized-losses  wheel-base    length  \
# symboling           1.000000           0.466264   -0.535987 -0.365404
# normalized-losses   0.466264           1.000000   -0.056661  0.019424
# wheel-base         -0.535987          -0.056661    1.000000  0.876024
# length             -0.365404           0.019424    0.876024  1.000000
# width              -0.242423           0.086802    0.814507  0.857170
# height             -0.550160          -0.373737    0.590742  0.492063
# curb-weight        -0.233118           0.099404    0.782097  0.880665
# engine-size        -0.110581           0.112360    0.572027  0.685025
# bore               -0.140019          -0.029862    0.493244  0.608971
# stroke             -0.008245           0.055563    0.158502  0.124139
# compression-ratio  -0.182196          -0.114713    0.250313  0.159733
# horsepower          0.075819           0.217299    0.371147  0.579821
# peak-rpm            0.279740           0.239543   -0.360305 -0.285970
# city-mpg           -0.035527          -0.225016   -0.470606 -0.665192
# highway-mpg         0.036233          -0.181877   -0.543304 -0.698142
# price              -0.082391           0.133999    0.584642  0.690628
# city-L/100km        0.066171           0.238567    0.476153  0.657373
# diesel             -0.196735          -0.101546    0.307237  0.211187
# gas                 0.196735           0.101546   -0.307237 -0.211187
#
#                       width    height  curb-weight  engine-size      bore  \
# symboling         -0.242423 -0.550160    -0.233118    -0.110581 -0.140019
# normalized-losses  0.086802 -0.373737     0.099404     0.112360 -0.029862
# wheel-base         0.814507  0.590742     0.782097     0.572027  0.493244
# length             0.857170  0.492063     0.880665     0.685025  0.608971
# width              1.000000  0.306002     0.866201     0.729436  0.544885
# height             0.306002  1.000000     0.307581     0.074694  0.180449
# curb-weight        0.866201  0.307581     1.000000     0.849072  0.644060
# engine-size        0.729436  0.074694     0.849072     1.000000  0.572609
# bore               0.544885  0.180449     0.644060     0.572609  1.000000
# stroke             0.188829 -0.062704     0.167562     0.209523 -0.055390
# compression-ratio  0.189867  0.259737     0.156433     0.028889  0.001263
# horsepower         0.615077 -0.087027     0.757976     0.822676  0.566936
# peak-rpm          -0.245800 -0.309974    -0.279361    -0.256733 -0.267392
# city-mpg          -0.633531 -0.049800    -0.749543    -0.650546 -0.582027
# highway-mpg       -0.680635 -0.104812    -0.794889    -0.679571 -0.591309
# price              0.751265  0.135486     0.834415     0.872335  0.543155
# city-L/100km       0.673363  0.003811     0.785353     0.745059  0.554610
# diesel             0.244356  0.281578     0.221046     0.070779  0.054458
# gas               -0.244356 -0.281578    -0.221046    -0.070779 -0.054458
#
#                      stroke  compression-ratio  horsepower  peak-rpm  \
# symboling         -0.008245          -0.182196    0.075819  0.279740
# normalized-losses  0.055563          -0.114713    0.217299  0.239543
# wheel-base         0.158502           0.250313    0.371147 -0.360305
# length             0.124139           0.159733    0.579821 -0.285970
# width              0.188829           0.189867    0.615077 -0.245800
# height            -0.062704           0.259737   -0.087027 -0.309974
# curb-weight        0.167562           0.156433    0.757976 -0.279361
# engine-size        0.209523           0.028889    0.822676 -0.256733
# bore              -0.055390           0.001263    0.566936 -0.267392
# stroke             1.000000           0.187923    0.098462 -0.065713
# compression-ratio  0.187923           1.000000   -0.214514 -0.435780
# horsepower         0.098462          -0.214514    1.000000  0.107885
# peak-rpm          -0.065713          -0.435780    0.107885  1.000000
# city-mpg          -0.034696           0.331425   -0.822214 -0.115413
# highway-mpg       -0.035201           0.268465   -0.804575 -0.058598
# price              0.082310           0.071107    0.809575 -0.101616
# city-L/100km       0.037300          -0.299372    0.889488  0.115830
# diesel             0.241303           0.985231   -0.169053 -0.475812
# gas               -0.241303          -0.985231    0.169053  0.475812
#
#                    city-mpg  highway-mpg     price  city-L/100km    diesel  \
# symboling         -0.035527     0.036233 -0.082391      0.066171 -0.196735
# normalized-losses -0.225016    -0.181877  0.133999      0.238567 -0.101546
# wheel-base        -0.470606    -0.543304  0.584642      0.476153  0.307237
# length            -0.665192    -0.698142  0.690628      0.657373  0.211187
# width             -0.633531    -0.680635  0.751265      0.673363  0.244356
# height            -0.049800    -0.104812  0.135486      0.003811  0.281578
# curb-weight       -0.749543    -0.794889  0.834415      0.785353  0.221046
# engine-size       -0.650546    -0.679571  0.872335      0.745059  0.070779
# bore              -0.582027    -0.591309  0.543155      0.554610  0.054458
# stroke            -0.034696    -0.035201  0.082310      0.037300  0.241303
# compression-ratio  0.331425     0.268465  0.071107     -0.299372  0.985231
# horsepower        -0.822214    -0.804575  0.809575      0.889488 -0.169053
# peak-rpm          -0.115413    -0.058598 -0.101616      0.115830 -0.475812
# city-mpg           1.000000     0.972044 -0.686571     -0.949713  0.265676
# highway-mpg        0.972044     1.000000 -0.704692     -0.930028  0.198690
# price             -0.686571    -0.704692  1.000000      0.789898  0.110326
# city-L/100km      -0.949713    -0.930028  0.789898      1.000000 -0.241282
# diesel             0.265676     0.198690  0.110326     -0.241282  1.000000
# gas               -0.265676    -0.198690 -0.110326      0.241282 -1.000000
#
#                         gas
# symboling          0.196735
# normalized-losses  0.101546
# wheel-base        -0.307237
# length            -0.211187
# width             -0.244356
# height            -0.281578
# curb-weight       -0.221046
# engine-size       -0.070779
# bore              -0.054458
# stroke            -0.241303
# compression-ratio -0.985231
# horsepower         0.169053
# peak-rpm           0.475812
# city-mpg          -0.265676
# highway-mpg       -0.198690
# price             -0.110326
# city-L/100km       0.241282
# diesel            -1.000000
# gas                1.000000

# %% [markdown]
# La diagonal siempre es 1.

# %%
df[['wheel-base', 'length', 'width', 'curb-weight', 'engine-size', 'highway-mpg', 'peak-rpm','price']].corr()
# Out:
#              wheel-base    length     width  curb-weight  engine-size  \
# wheel-base     1.000000  0.876024  0.814507     0.782097     0.572027
# length         0.876024  1.000000  0.857170     0.880665     0.685025
# width          0.814507  0.857170  1.000000     0.866201     0.729436
# curb-weight    0.782097  0.880665  0.866201     1.000000     0.849072
# engine-size    0.572027  0.685025  0.729436     0.849072     1.000000
# highway-mpg   -0.543304 -0.698142 -0.680635    -0.794889    -0.679571
# peak-rpm      -0.360305 -0.285970 -0.245800    -0.279361    -0.256733
# price          0.584642  0.690628  0.751265     0.834415     0.872335
#
#              highway-mpg  peak-rpm     price
# wheel-base     -0.543304 -0.360305  0.584642
# length         -0.698142 -0.285970  0.690628
# width          -0.680635 -0.245800  0.751265
# curb-weight    -0.794889 -0.279361  0.834415
# engine-size    -0.679571 -0.256733  0.872335
# highway-mpg     1.000000 -0.058598 -0.704692
# peak-rpm       -0.058598  1.000000 -0.101616
# price          -0.704692 -0.101616  1.000000

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <h1> Pregunta  #2: </h1>
#
# <p>Encontrar la correlación entre las variables : bore, stroke,compression-ratio  y horsepower.</p>
# </div>

# %%
# Solucion
df[['bore', 'stroke', 'compression-ratio', 'horsepower']].corr()
# Out:
#                        bore    stroke  compression-ratio  horsepower
# bore               1.000000 -0.055390           0.001263    0.566936
# stroke            -0.055390  1.000000           0.187923    0.098462
# compression-ratio  0.001263  0.187923           1.000000   -0.214514
# horsepower         0.566936  0.098462          -0.214514    1.000000

# %%
sns.heatmap(abs(df[['bore','stroke','compression-ratio','horsepower']].corr()),annot=True,fmt=".1f",cmap="Blues")
# Out:
# <Axes: >

# %%
dfx = df[['wheel-base', 'length', 'width', 'curb-weight', 'engine-size']].corr() 
dfx
# Out:
#              wheel-base    length     width  curb-weight  engine-size
# wheel-base     1.000000  0.876024  0.814507     0.782097     0.572027
# length         0.876024  1.000000  0.857170     0.880665     0.685025
# width          0.814507  0.857170  1.000000     0.866201     0.729436
# curb-weight    0.782097  0.880665  0.866201     1.000000     0.849072
# engine-size    0.572027  0.685025  0.729436     0.849072     1.000000

# %%
sns.heatmap(abs(dfx),annot=True,fmt=".1f",cmap="Blues")
# Out:
# <Axes: >

# %%
dfx = df[['bore', 'stroke', 'compression-ratio', 'horsepower']].corr() 
dfx
# Out:
#                        bore    stroke  compression-ratio  horsepower
# bore               1.000000 -0.055390           0.001263    0.566936
# stroke            -0.055390  1.000000           0.187923    0.098462
# compression-ratio  0.001263  0.187923           1.000000   -0.214514
# horsepower         0.566936  0.098462          -0.214514    1.000000

# %%
sns.heatmap(abs(dfx),annot=True,fmt=".1f",cmap="Blues")
# Out:
# <Axes: >

# %% [markdown]
# <h2>2.1.- Variables númericas continuas: (Análisis Bivariado)</h2>
#
# <p>Son variables que pueden contener cualquier valor en algun rango, son de tipo "int64" o "float64". Una excelente manera de visualizar estas variables es mediante el uso de diagramas de dispersión con líneas ajustadas.</p>
#
# <p>Para comenzar a comprender la relación (lineal) entre una variable individual y el "price". Podemos hacer esto usando "regplot", que traza el diagrama de dispersión más la línea de regresión ajustada para los datos.</p>

# %% [markdown]
# <h4>Relaciones positivas lineales</h4>

# %% [markdown]
# Busquemos el diagrama de dispersión de "engine-size" y "price"

# %%
# Engine size as potential predictor variable of price
#sns.regplot(x="engine-size", y="price", data=df)
sns.regplot(x="engine-size", y="price", data=df, fit_reg=False)
plt.ylim(0,)
# Out:
# /var/folders/c7/p02yvsh9697_g6yclqsn8p440000gn/T/ipykernel_28094/1725052805.py:4: UserWarning: Attempting to set identical low and high ylims makes transformation singular; automatically expanding.
#   plt.ylim(0,)
# (-0.05, 0.05)

# %% [markdown]
# <p>A medida que aumenta el tamaño del motor, aumenta el precio: esto indica una correlación directa positiva entre estas dos variables. El tamaño del motor parece un buen predictor de precio ya que la línea de regresión es casi una línea diagonal perfecta.</p>

# %% [markdown]
# Podemos examinar la correlación entre 'engine-size' y 'price' y ver que es aproximadamente 0.87

# %%
df[["engine-size", "price"]].corr()
# Out:
#              engine-size     price
# engine-size     1.000000  0.872335
# price           0.872335  1.000000

# %% [markdown]
# Busquemos el diagrama de dispersión de "highway-mpg" y "price"

# %%
#sns.regplot(x="highway-mpg", y="price", data=df)
sns.regplot(x="highway-mpg", y="price", data=df, fit_reg=False)
# Out:
# <Axes: xlabel='highway-mpg', ylabel='price'>

# %% [markdown]
# <p>A medida que sube el highway-mpg, el price baja: esto indica una relación inversa / negativa entre estas dos variables. El highway-mpg podría ser un potencial predictor para el price.</p>

# %% [markdown]
# La correlación entre 'highway-mpg' y 'price' es aproximadamente  -0.704

# %%
df[['highway-mpg', 'price']].corr()
# Out:
#              highway-mpg     price
# highway-mpg     1.000000 -0.704692
# price          -0.704692  1.000000

# %% [markdown]
# <h3>Relaciones lineales débiles</h3>

# %% [markdown]
# Se analiza "peak-rpm" como una variable predictora / variable objetivo de "price".

# %%
#sns.regplot(x="peak-rpm", y="price", data=df)
sns.regplot(x="peak-rpm", y="price", data=df, fit_reg=True)
# Out:
# <Axes: xlabel='peak-rpm', ylabel='price'>

# %% [markdown]
# <p>Las peak-rpm no parecen ser un buen predictor al price, ya que la línea de regresión está cerca de la horizontal. Además, los puntos de datos están muy dispersos y lejos de la línea ajustada, lo que muestra mucha variabilidad. Por lo tanto, no es una variable confiable.</p>

# %% [markdown]
# La correlación entre 'peak-rpm' y 'price' es aproximadamente -0.101616

# %%
df[['peak-rpm','price']].corr()
# Out:
#           peak-rpm     price
# peak-rpm  1.000000 -0.101616
# price    -0.101616  1.000000

# %% [markdown]
#  <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <h1> Pregunta  3 a): </h1>
#
# <p>Encontrar la correlación entre x="stroke", y="price".</p>
# </div>

# %%
# Respuesta
df[['stroke', 'price']].corr()
# Out:
#          stroke    price
# stroke  1.00000  0.08231
# price   0.08231  1.00000

# %%
sns.regplot(x="stroke", y="price", data=df, fit_reg=True)

dfy = df[['stroke','price']].corr()
dfy
# Out:
#          stroke    price
# stroke  1.00000  0.08231
# price   0.08231  1.00000

# %% [markdown]
# Double-click <b>here</b> for the solution.
#
# <!-- The answer is below:
#
# #The correlation is 0.0823, the non-diagonal elements of the table.
# #code:
# df[["stroke","price"]].corr()
#
# -->

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <h1>Question  3 b):</h1>
#
# <p>Analizar el resultado de la correlacion entre el  "price" y "stroke", tiene una relación lineal?</p>
# <p>Verifica los resultados con la función  "regplot()".</p>
# </div>

# %%
# Resultado: 
#sns.regplot(x="stroke", y="price", data=df)
sns.regplot(x="stroke", y="price", data=df, fit_reg=False)
# Out:
# <Axes: xlabel='stroke', ylabel='price'>

# %% [markdown]
# Double-click <b>here</b> for the solution.
#
# <!-- The answer is below:
#
# #There is a weak correlation between the variable 'stroke' and 'price.' as such regression will not work well.  We #can see this use "regplot" to demonstrate this.
#
# #Code:
# sns.regplot(x="stroke", y="price", data=df)
#
# -->

# %% [markdown]
# <h3>2.2.- Variables categoricas</h3>
#
# <p>Estas son variables que describen una 'característica' de una unidad de datos y se seleccionan de un pequeño grupo de categorías. Las variables categóricas pueden tener el tipo "objeto" o "int64". Una buena forma de visualizar variables categóricas es mediante el uso de diagramas de caja.</p>

# %% [markdown]
# Se revisa la relación entre "body-style" y "price".

# %%
df["body-style"].value_counts()
# Out:
# body-style
# sedan          94
# hatchback      68
# wagon          25
# hardtop         8
# convertible     6
# Name: count, dtype: int64

# %%
sns.boxplot(x="body-style", y="price", data=df)
# Out:
# <Axes: xlabel='stroke', ylabel='price'>

# %% [markdown]
# <p> Vemos que las distribuciones de precios entre las diferentes categorías de estilo de cuerpo (body-style) tienen una superposición significativa, por lo que el estilo de cuerpo no sería un buen predictor del precio.
#
#  Examinemos la "engine-location" y "price": </p>

# %%
df["engine-location"].value_counts()
# Out:
# engine-location
# front    198
# rear       3
# Name: count, dtype: int64

# %%
sns.boxplot(x="engine-location", y="price", data=df)
# Out:
# <Axes: xlabel='stroke', ylabel='price'>

# %% [markdown]
# <p>Aquí vemos que la distribución del precio entre estas dos categorías de ubicación del motor (engine-location), front y rear, es lo suficientemente distinta como para tomar la ubicación del motor como un buen predictor potencial del precio.</p>

# %% [markdown]
#  Examinando la relación entre  "drive-wheels" y "price".

# %%
df["drive-wheels"].value_counts()
# Out:
# drive-wheels
# fwd    118
# rwd     75
# 4wd      8
# Name: count, dtype: int64

# %%
# drive-wheels
sns.boxplot(x="drive-wheels", y="price", data=df)
# Out:
# <Axes: xlabel='stroke', ylabel='price'>

# %% [markdown]
# <p>Aquí vemos que la distribución de precios (price) entre las diferentes categorías de ruedas motrices(drive-wheels)  es diferente solo en un caso; Como tal, las ruedas motrices (drive-wheels) no podrían ser un predictor de precio.</p>

# %%
df["num-of-cylinders"].value_counts()
# Out:
# num-of-cylinders
# four      157
# six        24
# five       10
# two         4
# eight       4
# three       1
# twelve      1
# Name: count, dtype: int64

# %%
# num-of-cylinders
sns.boxplot(x="num-of-cylinders", y="price", data=df)
# Out:
# <Axes: xlabel='stroke', ylabel='price'>

# %%
# fuel-system
sns.boxplot(x="fuel-system", y="price", data=df)
# Out:
# <Axes: xlabel='stroke', ylabel='price'>

# %% [markdown]
# <h2 id="discriptive_statistics">3. Análisis estadístico descriptivo</h2>

# %% [markdown]
# <p>La funcion <b>describe</b> calcula automáticamente estadísticas básicas para todas las variables continuas. Cualquier valor de NaN se omite automáticamente en estas estadísticas.</p>
#
# Se mostrara los siguientes valores:
# <ul>
#     <li>Contador de variables</li>
#     <li>La media</li>
#     <li>La desviación estandar(std)</li>
#     <li>El valor minimo</li>
#     <li>El IQR (Rango intercuartil: 25%, 50% and 75%)</li>
#     <li>El valor máximoe</li>
# <ul>

# %%
df.describe()
# Out:
#         symboling  normalized-losses  wheel-base      length       width  \
# count  201.000000          201.00000  201.000000  201.000000  201.000000
# mean     0.840796          122.00000   98.797015    0.837102    0.915126
# std      1.254802           31.99625    6.066366    0.059213    0.029187
# min     -2.000000           65.00000   86.600000    0.678039    0.837500
# 25%      0.000000          101.00000   94.500000    0.801538    0.890278
# 50%      1.000000          122.00000   97.000000    0.832292    0.909722
# 75%      2.000000          137.00000  102.400000    0.881788    0.925000
# max      3.000000          256.00000  120.900000    1.000000    1.000000
#
#            height  curb-weight  engine-size        bore      stroke  \
# count  201.000000   201.000000   201.000000  201.000000  197.000000
# mean    53.766667  2555.666667   126.875622    3.330692    3.256904
# std      2.447822   517.296727    41.546834    0.268072    0.319256
# min     47.800000  1488.000000    61.000000    2.540000    2.070000
# 25%     52.000000  2169.000000    98.000000    3.150000    3.110000
# 50%     54.100000  2414.000000   120.000000    3.310000    3.290000
# 75%     55.500000  2926.000000   141.000000    3.580000    3.410000
# max     59.800000  4066.000000   326.000000    3.940000    4.170000
#
#        compression-ratio  horsepower     peak-rpm    city-mpg  highway-mpg  \
# count         201.000000  201.000000   201.000000  201.000000   201.000000
# mean           10.164279  103.405534  5117.665368   25.179104    30.686567
# std             4.004965   37.365700   478.113805    6.423220     6.815150
# min             7.000000   48.000000  4150.000000   13.000000    16.000000
# 25%             8.600000   70.000000  4800.000000   19.000000    25.000000
# 50%             9.000000   95.000000  5125.369458   24.000000    30.000000
# 75%             9.400000  116.000000  5500.000000   30.000000    34.000000
# max            23.000000  262.000000  6600.000000   49.000000    54.000000
#
#               price  city-L/100km      diesel         gas
# count    201.000000    201.000000  201.000000  201.000000
# mean   13207.129353      9.944145    0.099502    0.900498
# std     7947.066342      2.534599    0.300083    0.300083
# min     5118.000000      4.795918    0.000000    0.000000
# 25%     7775.000000      7.833333    0.000000    1.000000
# 50%    10295.000000      9.791667    0.000000    1.000000
# 75%    16500.000000     12.368421    0.000000    1.000000
# max    45400.000000     18.076923    1.000000    1.000000

# %% [markdown]
#  The default setting of "describe" skips variables of type object. We can apply the method "describe" on the variables of type 'object' as follows:

# %%
df.describe(include=['object'])
# Out:
#           make aspiration num-of-doors body-style drive-wheels  \
# count      201        201          201        201          201
# unique      22          2            2          5            3
# top     toyota        std         four      sedan          fwd
# freq        32        165          115         94          118
#
#        engine-location engine-type num-of-cylinders fuel-system  \
# count              201         201              201         201
# unique               2           6                7           8
# top              front         ohc             four        mpfi
# freq               198         145              157          92
#
#        horsepower-binned
# count                200
# unique                 3
# top                  Low
# freq                 115

# %% [markdown]
# <h3>3.1.- Contar valores</h3>

# %% [markdown]
# <p>El conteo de valores es una buena forma de entender cuántas unidades de cada característica / variable tenemos. Podemos aplicar el método "value_counts" en la columna 'drive-wheels'. No olvide que el método "value_counts" solo funciona en series Pandas, no en Pandas Dataframes. Como resultado, solo incluimos un soporte "df['drive-wheels']" no dos soportes "df[['drive-wheels']]".</p>

# %%
df['drive-wheels'].value_counts()
# Out:
# drive-wheels
# fwd    118
# rwd     75
# 4wd      8
# Name: count, dtype: int64

# %% [markdown]
# Convertir la seria a un dataframe de la siguiente manera:

# %%
df['drive-wheels'].value_counts().to_frame()
# Out:
#               count
# drive-wheels
# fwd             118
# rwd              75
# 4wd               8

# %% [markdown]
# Se repite los pasos anteriores, pero se guarda los resultados en datframe "drive_wheels_counts" y se cambie el nombre de la columna 'drive-wheels' a 'value_counts'.

# %%
drive_wheels_counts = df['drive-wheels'].value_counts().to_frame()

drive_wheels_counts.rename(columns={'drive-wheels': 'counts'}, inplace=True)
drive_wheels_counts
# Out:
#               count
# drive-wheels
# fwd             118
# rwd              75
# 4wd               8

# %% [markdown]
#  Se renombra el index a : 'drive-wheels':

# %%
drive_wheels_counts.index.name = 'drive-wheels'
drive_wheels_counts
# Out:
#               count
# drive-wheels
# fwd             118
# rwd              75
# 4wd               8

# %% [markdown]
# Se repite lo mismo para la variable : 'engine-location'.

# %%
# engine-location as variable
engine_loc_counts = df['engine-location'].value_counts().to_frame()
engine_loc_counts.rename(columns={'engine-location': 'value_counts'}, inplace=True)
engine_loc_counts.index.name = 'engine-location'
engine_loc_counts.head(10)
# Out:
#                  count
# engine-location
# front              198
# rear                 3

# %% [markdown]
# <p>
# Examinando el valor del conteo de la ubicación del motor (engine-location) no sería una buena variable predictiva del precio. Esto se debe a que solo tenemos tres autos con motor trasero (rear) y 198 con motor delantero (front), este resultado es muy sesgado. Por lo tanto, no podemos sacar ninguna conclusión sobre la ubicación del motor.
# </p>

# %% [markdown]
# <h2 id="basic_grouping">4.
# Conceptos básicos de agrupación</h2>

# %% [markdown]
# <p>El método  "groupby" agrupa datos por categorias.Los datos se agrupan en función de una o varias variables y el análisis se realiza en los grupos individuales..</p>
#
# <p>Se agrupa la variable "drive-wheels". Se observan 3 tipos de categorias.</p>

# %%
df['drive-wheels'].unique()
# Out:
# array(['rwd', 'fwd', '4wd'], dtype=object)

# %% [markdown]
# <p>Si queremos saber, en promedio, qué tipo de rueda motriz es más valiosa, podemos agrupar las "drive-wheels" y luego promediarlas..</p>
#
# <p>Podemos seleccionar las columnas 'drive-wheels', 'body-style' y 'price', luego asignarlo a la variable "df_group_one".</p>

# %%
df_group_one = df[['drive-wheels','body-style','price']]

# %% [markdown]
# Luego podemos calcular el precio promedio para cada una de las diferentes categorías de datos

# %%
df_group_one.head()
# Out:
#   drive-wheels   body-style    price
# 0          rwd  convertible  13495.0
# 1          rwd  convertible  16500.0
# 2          rwd    hatchback  16500.0
# 3          fwd        sedan  13950.0
# 4          4wd        sedan  17450.0

# %%
# grouping results
df_group_one_tmp = df_group_one.groupby(['drive-wheels'],as_index=True).mean(numeric_only=True)
df_group_one_tmp
# Out:
#                      price
# drive-wheels
# 4wd           10241.000000
# fwd            9244.779661
# rwd           19757.613333

# %%
# grouping results
df_group_one_tmp = df_group_one.groupby(['drive-wheels'],as_index=False).mean(numeric_only=True)
df_group_one_tmp
# Out:
#   drive-wheels         price
# 0          4wd  10241.000000
# 1          fwd   9244.779661
# 2          rwd  19757.613333

# %% [markdown]
# <p>
# Según nuestros datos, parece que los vehículos con tracción trasera  (rear-wheel) son, en promedio, los más caros, mientras que las 4 ruedas (4-wheel) y las ruedas delanteras (front-wheel) tienen aproximadamente el mismo precio.
# </p>
#
# <p>
# También puede agrupar con múltiples variables. Por ejemplo, agrupemos por ''drive-wheels' y 'body-style'. Esto agrupa el marco de datos por las combinaciones únicas 'drive-wheels' y 'body-style'. Podemos almacenar los resultados en la variable 'grouped_test1'.</p>

# %%
# Calcular el precio promedio de los autos de segunda por 
# tipo de carroceria.

df_group_x = df[["body-style","price"]]
df_group_y = df_group_x.groupby(["body-style"],as_index=True).mean()
df_group_y
# Out:
#                     price
# body-style
# convertible  21890.500000
# hardtop      22208.500000
# hatchback     9957.441176
# sedan        14459.755319
# wagon        12371.960000

# %%
# Grouping by two categories variables
df_gptest = df[['drive-wheels','body-style','price']]
grouped_test1 = df_gptest.groupby(['drive-wheels','body-style'],as_index=False).mean(numeric_only=True)
grouped_test1
# Out:
#    drive-wheels   body-style         price
# 0           4wd    hatchback   7603.000000
# 1           4wd        sedan  12647.333333
# 2           4wd        wagon   9095.750000
# 3           fwd  convertible  11595.000000
# 4           fwd      hardtop   8249.000000
# 5           fwd    hatchback   8396.387755
# 6           fwd        sedan   9811.800000
# 7           fwd        wagon   9997.333333
# 8           rwd  convertible  23949.600000
# 9           rwd      hardtop  24202.714286
# 10          rwd    hatchback  14337.777778
# 11          rwd        sedan  21711.833333
# 12          rwd        wagon  16994.222222

# %% [markdown]
# <p>Estos datos agrupados son mucho más fáciles de visualizar cuando se convierten en una pivot table. Una pivot table es como una hoja de cálculo de Excel, con una variable a lo largo de la columna y otra a lo largo de la fila. Podemos convertir un dataframe en una tabla dinámica utilizando el método "pivot" para crear una pivot table desde grupos
# </p>
#
# <p>En este caso, dejaremos la variable de la rueda motriz (drive-wheel) como las filas de la tabla y giraremos el estilo del cuerpo (body-style ) para convertirlas en las columnas de la tabla:</p>

# %%
grouped_pivot = grouped_test1.pivot(index='drive-wheels',columns='body-style')
grouped_pivot.head()
# Out:
#                    price                                            \
# body-style   convertible       hardtop     hatchback         sedan
# drive-wheels
# 4wd                  NaN           NaN   7603.000000  12647.333333
# fwd              11595.0   8249.000000   8396.387755   9811.800000
# rwd              23949.6  24202.714286  14337.777778  21711.833333
#
#
# body-style           wagon
# drive-wheels
# 4wd            9095.750000
# fwd            9997.333333
# rwd           16994.222222

# %%
# Grouping by two categories variables
df_gp_three = df[['drive-wheels','engine-location','body-style','price']]
grouped_test3 = df_gp_three.groupby(['drive-wheels','body-style','engine-location'],as_index=False).mean(numeric_only=True)
grouped_test3
# Out:
#    drive-wheels   body-style engine-location         price
# 0           4wd    hatchback           front   7603.000000
# 1           4wd        sedan           front  12647.333333
# 2           4wd        wagon           front   9095.750000
# 3           fwd  convertible           front  11595.000000
# 4           fwd      hardtop           front   8249.000000
# 5           fwd    hatchback           front   8396.387755
# 6           fwd        sedan           front   9811.800000
# 7           fwd        wagon           front   9997.333333
# 8           rwd  convertible           front  20680.000000
# 9           rwd  convertible            rear  37028.000000
# 10          rwd      hardtop           front  20572.600000
# 11          rwd      hardtop            rear  33278.000000
# 12          rwd    hatchback           front  14337.777778
# 13          rwd        sedan           front  21711.833333
# 14          rwd        wagon           front  16994.222222

# %%
#Grouping by three categories variables
"""
df_gp_three = df[['drive-wheels','engine-location','body-style','price']]
grouped_test3 = df_gp_three.groupby(['drive-wheels','body-style','engine-location'],as_index=False).mean()#
grouped_pivot_tmp = grouped_test3.pivot(index='drive-wheels',columns=['body-style','engine-location'])
grouped_pivot_tmp
"""
# Out:
# "\ndf_gp_three = df[['drive-wheels','engine-location','body-style','price']]\ngrouped_test3 = df_gp_three.groupby(['drive-wheels','body-style','engine-location'],as_index=False).mean()#\ngrouped_pivot_tmp = grouped_test3.pivot(index='drive-wheels',columns=['body-style','engine-location'])\ngrouped_pivot_tmp\n"

# %%
"""
df_tmp = pd.DataFrame({"lev1": [1, 1, 1, 2, 2, 2], 
       "lev2": [1, 1, 2, 1, 1, 2], 
       "lev3": [1, 2, 1, 2, 1, 2], 
       "lev4": [1, 2, 3, 4, 5, 6], 
       "values": [0, 1, 2, 3, 4, 5]})
df_tmp.pivot(index="lev1", columns=["lev2", "lev3"],values="values")
#df.head()
"""
# Out:
# '\ndf_tmp = pd.DataFrame({"lev1": [1, 1, 1, 2, 2, 2], \n       "lev2": [1, 1, 2, 1, 1, 2], \n       "lev3": [1, 2, 1, 2, 1, 2], \n       "lev4": [1, 2, 3, 4, 5, 6], \n       "values": [0, 1, 2, 3, 4, 5]})\ndf_tmp.pivot(index="lev1", columns=["lev2", "lev3"],values="values")\n#df.head()\n'

# %%
# Revisar convertir de pivot a dataframe original :
grouped_pivot = grouped_test1.pivot(index='drive-wheels',columns='body-style')
grouped_pivot.head()
# Out:
#                    price                                            \
# body-style   convertible       hardtop     hatchback         sedan
# drive-wheels
# 4wd                  NaN           NaN   7603.000000  12647.333333
# fwd              11595.0   8249.000000   8396.387755   9811.800000
# rwd              23949.6  24202.714286  14337.777778  21711.833333
#
#
# body-style           wagon
# drive-wheels
# 4wd            9095.750000
# fwd            9997.333333
# rwd           16994.222222

# %% [markdown]
# <p>
# A menudo, no tendremos datos para algunas de las celdas dinámicas. Podemos llenar estas celdas faltantes con el valor 0, pero cualquier otro valor también podría usarse. Cabe mencionar que la falta de datos es un tema bastante complejo y es un curso completo por sí solo.
# </p>

# %%
# Grouping by two categories variables
df_gptest = df[['drive-wheels','body-style','price']]
grouped_test1 = df_gptest.groupby(['drive-wheels','body-style'],as_index=False).mean()
grouped_pivot = grouped_test1.pivot(index='drive-wheels',columns='body-style')
grouped_pivot = grouped_pivot.fillna(0) #fill missing values with 0
grouped_pivot
# Out:
#                    price                                            \
# body-style   convertible       hardtop     hatchback         sedan
# drive-wheels
# 4wd                  0.0      0.000000   7603.000000  12647.333333
# fwd              11595.0   8249.000000   8396.387755   9811.800000
# rwd              23949.6  24202.714286  14337.777778  21711.833333
#
#
# body-style           wagon
# drive-wheels
# 4wd            9095.750000
# fwd            9997.333333
# rwd           16994.222222

# %%
grouped_pivot = round(grouped_pivot, 1)
grouped_pivot
# Out:
#                    price
# body-style   convertible  hardtop hatchback    sedan    wagon
# drive-wheels
# 4wd                  0.0      0.0    7603.0  12647.3   9095.8
# fwd              11595.0   8249.0    8396.4   9811.8   9997.3
# rwd              23949.6  24202.7   14337.8  21711.8  16994.2

# %%
grouped_pivot
# Out:
#                    price
# body-style   convertible  hardtop hatchback    sedan    wagon
# drive-wheels
# 4wd                  0.0      0.0    7603.0  12647.3   9095.8
# fwd              11595.0   8249.0    8396.4   9811.8   9997.3
# rwd              23949.6  24202.7   14337.8  21711.8  16994.2

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <h1>Pregunta 4:</h1>
#
# <p>Usar la funcion  "groupby" para encontrar el promedio del  "price" de cada auto basado en "body-style" ? </p>
# </div>

# %%
# Respuesta
df_gptest2 = df[['body-style','price']]
grouped_test_bodystyle = df_gptest2.groupby(['body-style'],as_index= False).mean()
grouped_test_bodystyle
# Out:
#     body-style         price
# 0  convertible  21890.500000
# 1      hardtop  22208.500000
# 2    hatchback   9957.441176
# 3        sedan  14459.755319
# 4        wagon  12371.960000

# %%
# Creacion de una funcion para obtener una TABLA PIVOT
grouped_test4  = df[['drive-wheels','body-style','price']]
grouped_test4  = grouped_test4.groupby(['drive-wheels','body-style'],as_index=False).mean()
grouped_pivot4 = grouped_test4.pivot(index='drive-wheels',columns='body-style')
grouped_pivot4 = round(grouped_pivot4.fillna(0), 2)
grouped_pivot4
# Out:
#                    price
# body-style   convertible   hardtop hatchback     sedan     wagon
# drive-wheels
# 4wd                  0.0      0.00   7603.00  12647.33   9095.75
# fwd              11595.0   8249.00   8396.39   9811.80   9997.33
# rwd              23949.6  24202.71  14337.78  21711.83  16994.22

# %%
# Respuesta
def convertir_pivot(nom_var1, nom_var2, nom_var_salida):
    grouped_test4  = df[[nom_var1,nom_var2,nom_var_salida]]
    grouped_test4  = grouped_test4.groupby([nom_var1,nom_var2],as_index=False).mean()
    grouped_pivot4 = grouped_test4.pivot(index=nom_var1,columns=nom_var2)
    grouped_pivot4 = round(grouped_pivot4.fillna(0), 2)
    return grouped_pivot4

# %%
tabla_pivot = convertir_pivot('drive-wheels','body-style','price')
tabla_pivot
# Out:
#                    price
# body-style   convertible   hardtop hatchback     sedan     wagon
# drive-wheels
# 4wd                  0.0      0.00   7603.00  12647.33   9095.75
# fwd              11595.0   8249.00   8396.39   9811.80   9997.33
# rwd              23949.6  24202.71  14337.78  21711.83  16994.22

# %%
tabla_pivot = convertir_pivot('engine-location','engine-type','price')
tabla_pivot
# Out:
#                     price
# engine-type          dohc         l       ohc      ohcf      ohcv    rotor
# engine-location
# front            18116.42  14627.58  11567.36   8541.25  25098.38  13020.0
# rear                 0.00      0.00      0.00  34528.00      0.00      0.0

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# <h4>Variables: Drive Wheels y Body Style vs Price</h4>

# %% [markdown]
# <p>
# El heatmap (mapa de calor) traza la variable objetivo (precio) proporcional al color con respecto a las variables 'drive-wheel' y 'body-style' en los ejes vertical y horizontal, respectivamente. Esto nos permite visualizar cómo se relaciona el precio con 'drive-wheel' y 'body-style'</p>

# %%
fig, ax = plt.subplots()
im = ax.pcolor(grouped_pivot, cmap='RdBu')

#label names
row_labels = grouped_pivot.columns.levels[1]
col_labels = grouped_pivot.index

#move ticks and labels to the center
ax.set_xticks(np.arange(grouped_pivot.shape[1]) + 0.5, minor=False)
ax.set_yticks(np.arange(grouped_pivot.shape[0]) + 0.5, minor=False)

#insert labels
ax.set_xticklabels(row_labels, minor=False)
ax.set_yticklabels(col_labels, minor=False)

#rotate label if too long
plt.xticks(rotation=90)

fig.colorbar(im, label="precio")
plt.show()

# %%
sns.heatmap(grouped_pivot,annot=True,fmt=".1f",cmap="Blues")
plt.show()

# %% [markdown]
# <p>La visualización es muy importante en la ciencia de datos, y los paquetes de visualización de Python proporcionan una gran libertad. </p>
#
# <p>La pregunta principal que queremos responder en este módulo es "¿Cuáles son las principales características que tienen el mayor impacto en el precio del automóvil?". </p>
#
# <p> Para obtener una mejor medición de las características importantes, observamos la correlación de estas variables con el precio del automóvil, en otras palabras: ¿cómo depende el precio del automóvil de esta variable? </p>

# %%
# grouping results
df_gptest2 = df[['fuel-system','num-of-cylinders','price']]
grouped_test2 = df_gptest2.groupby(['fuel-system','num-of-cylinders'],as_index=False).mean()
grouped_test2
# Out:
#    fuel-system num-of-cylinders         price
# 0         1bbl             four   7555.545455
# 1         2bbl             four   7469.428571
# 2         2bbl            three   5151.000000
# 3         4bbl              two  12145.000000
# 4          idi             five  28394.000000
# 5          idi             four  12047.800000
# 6          idi              six  22470.000000
# 7          mfi             four  12964.000000
# 8         mpfi            eight  38900.000000
# 9         mpfi             five  17750.000000
# 10        mpfi             four  13338.140351
# 11        mpfi              six  23724.086957
# 12        mpfi           twelve  36000.000000
# 13        mpfi              two  15645.000000
# 14        spdi             four  10990.444444
# 15        spfi             four  11048.000000

# %%
grouped_pivot2 = grouped_test2.pivot(index='fuel-system',columns='num-of-cylinders')
grouped_pivot2
# Out:
#                     price                                               \
# num-of-cylinders    eight     five          four           six   three
# fuel-system
# 1bbl                  NaN      NaN   7555.545455           NaN     NaN
# 2bbl                  NaN      NaN   7469.428571           NaN  5151.0
# 4bbl                  NaN      NaN           NaN           NaN     NaN
# idi                   NaN  28394.0  12047.800000  22470.000000     NaN
# mfi                   NaN      NaN  12964.000000           NaN     NaN
# mpfi              38900.0  17750.0  13338.140351  23724.086957     NaN
# spdi                  NaN      NaN  10990.444444           NaN     NaN
# spfi                  NaN      NaN  11048.000000           NaN     NaN
#
#
# num-of-cylinders   twelve      two
# fuel-system
# 1bbl                  NaN      NaN
# 2bbl                  NaN      NaN
# 4bbl                  NaN  12145.0
# idi                   NaN      NaN
# mfi                   NaN      NaN
# mpfi              36000.0  15645.0
# spdi                  NaN      NaN
# spfi                  NaN      NaN

# %%
grouped_pivot2 = grouped_pivot2.fillna(0) #fill missing values with 0
grouped_pivot2
# Out:
#                     price                                               \
# num-of-cylinders    eight     five          four           six   three
# fuel-system
# 1bbl                  0.0      0.0   7555.545455      0.000000     0.0
# 2bbl                  0.0      0.0   7469.428571      0.000000  5151.0
# 4bbl                  0.0      0.0      0.000000      0.000000     0.0
# idi                   0.0  28394.0  12047.800000  22470.000000     0.0
# mfi                   0.0      0.0  12964.000000      0.000000     0.0
# mpfi              38900.0  17750.0  13338.140351  23724.086957     0.0
# spdi                  0.0      0.0  10990.444444      0.000000     0.0
# spfi                  0.0      0.0  11048.000000      0.000000     0.0
#
#
# num-of-cylinders   twelve      two
# fuel-system
# 1bbl                  0.0      0.0
# 2bbl                  0.0      0.0
# 4bbl                  0.0  12145.0
# idi                   0.0      0.0
# mfi                   0.0      0.0
# mpfi              36000.0  15645.0
# spdi                  0.0      0.0
# spfi                  0.0      0.0

# %%
fig, ax = plt.subplots(figsize = (5, 5))

im = ax.pcolor(grouped_pivot2, cmap='RdBu')

#label names
row_labels = grouped_pivot2.columns.levels[1]
col_labels = grouped_pivot2.index

#move ticks and labels to the center
ax.set_xticks(np.arange(grouped_pivot2.shape[1]) + 0.5, minor=False)
ax.set_yticks(np.arange(grouped_pivot2.shape[0]) + 0.5, minor=False)

#insert labels
ax.set_xticklabels(row_labels, minor=False)
ax.set_yticklabels(col_labels, minor=False)

ax.set_ylabel("y")
ax.set_xlabel("x")

#rotate label if too long
plt.xticks(rotation=90)

fig.colorbar(im)
plt.show()

# %%
sns.heatmap(grouped_pivot2,annot=True,fmt=".1f",cmap="Blues")
plt.show()

# %% [markdown]
# <h2 id="correlation_causation">5. Correlacion y Causalidad</h2>

# %% [markdown]
# <p> <b> Correlación </b>: una medida del grado de interdependencia entre variables. </p>
#
# <p> <b> Causalidad </b>: la relación entre causa y efecto entre dos variables. </p>
#
# <p> Es importante saber que la correlación no implica causalidad. Determinar la correlación es mucho más simple que la causalidad determinante ya que la causalidad puede requerir experimentación independiente. </p>

# %% [markdown]
# <p3> <b>Correlación de Pearson</b> </p3>
# <p> La Correlación de Pearson mide la dependencia lineal entre dos variables X e Y. </p>
# <p> El coeficiente resultante es un valor entre -1 y 1, donde: </p>
# <ul>
#     <li> <b> 1 </b>: correlación lineal positiva perfecta </li>
#     <li> <b> 0 </b>: Sin correlación lineal, las dos variables probablemente no se afectan entre sí. </li>
#     <li> <b> -1 </b>: correlación lineal negativa perfecta </li>
# </ul>

# %% [markdown]
# <p> Correlación de Pearson es el método predeterminado de la función <b>"corr"</b>.Se puede  calcular la correlación de Pearson de las variables 'int64' o 'float64'. </p>

# %%
df.corr(numeric_only=True)
# Out:
#                    symboling  normalized-losses  wheel-base    length  \
# symboling           1.000000           0.466264   -0.535987 -0.365404
# normalized-losses   0.466264           1.000000   -0.056661  0.019424
# wheel-base         -0.535987          -0.056661    1.000000  0.876024
# length             -0.365404           0.019424    0.876024  1.000000
# width              -0.242423           0.086802    0.814507  0.857170
# height             -0.550160          -0.373737    0.590742  0.492063
# curb-weight        -0.233118           0.099404    0.782097  0.880665
# engine-size        -0.110581           0.112360    0.572027  0.685025
# bore               -0.140019          -0.029862    0.493244  0.608971
# stroke             -0.008245           0.055563    0.158502  0.124139
# compression-ratio  -0.182196          -0.114713    0.250313  0.159733
# horsepower          0.075819           0.217299    0.371147  0.579821
# peak-rpm            0.279740           0.239543   -0.360305 -0.285970
# city-mpg           -0.035527          -0.225016   -0.470606 -0.665192
# highway-mpg         0.036233          -0.181877   -0.543304 -0.698142
# price              -0.082391           0.133999    0.584642  0.690628
# city-L/100km        0.066171           0.238567    0.476153  0.657373
# diesel             -0.196735          -0.101546    0.307237  0.211187
# gas                 0.196735           0.101546   -0.307237 -0.211187
#
#                       width    height  curb-weight  engine-size      bore  \
# symboling         -0.242423 -0.550160    -0.233118    -0.110581 -0.140019
# normalized-losses  0.086802 -0.373737     0.099404     0.112360 -0.029862
# wheel-base         0.814507  0.590742     0.782097     0.572027  0.493244
# length             0.857170  0.492063     0.880665     0.685025  0.608971
# width              1.000000  0.306002     0.866201     0.729436  0.544885
# height             0.306002  1.000000     0.307581     0.074694  0.180449
# curb-weight        0.866201  0.307581     1.000000     0.849072  0.644060
# engine-size        0.729436  0.074694     0.849072     1.000000  0.572609
# bore               0.544885  0.180449     0.644060     0.572609  1.000000
# stroke             0.188829 -0.062704     0.167562     0.209523 -0.055390
# compression-ratio  0.189867  0.259737     0.156433     0.028889  0.001263
# horsepower         0.615077 -0.087027     0.757976     0.822676  0.566936
# peak-rpm          -0.245800 -0.309974    -0.279361    -0.256733 -0.267392
# city-mpg          -0.633531 -0.049800    -0.749543    -0.650546 -0.582027
# highway-mpg       -0.680635 -0.104812    -0.794889    -0.679571 -0.591309
# price              0.751265  0.135486     0.834415     0.872335  0.543155
# city-L/100km       0.673363  0.003811     0.785353     0.745059  0.554610
# diesel             0.244356  0.281578     0.221046     0.070779  0.054458
# gas               -0.244356 -0.281578    -0.221046    -0.070779 -0.054458
#
#                      stroke  compression-ratio  horsepower  peak-rpm  \
# symboling         -0.008245          -0.182196    0.075819  0.279740
# normalized-losses  0.055563          -0.114713    0.217299  0.239543
# wheel-base         0.158502           0.250313    0.371147 -0.360305
# length             0.124139           0.159733    0.579821 -0.285970
# width              0.188829           0.189867    0.615077 -0.245800
# height            -0.062704           0.259737   -0.087027 -0.309974
# curb-weight        0.167562           0.156433    0.757976 -0.279361
# engine-size        0.209523           0.028889    0.822676 -0.256733
# bore              -0.055390           0.001263    0.566936 -0.267392
# stroke             1.000000           0.187923    0.098462 -0.065713
# compression-ratio  0.187923           1.000000   -0.214514 -0.435780
# horsepower         0.098462          -0.214514    1.000000  0.107885
# peak-rpm          -0.065713          -0.435780    0.107885  1.000000
# city-mpg          -0.034696           0.331425   -0.822214 -0.115413
# highway-mpg       -0.035201           0.268465   -0.804575 -0.058598
# price              0.082310           0.071107    0.809575 -0.101616
# city-L/100km       0.037300          -0.299372    0.889488  0.115830
# diesel             0.241303           0.985231   -0.169053 -0.475812
# gas               -0.241303          -0.985231    0.169053  0.475812
#
#                    city-mpg  highway-mpg     price  city-L/100km    diesel  \
# symboling         -0.035527     0.036233 -0.082391      0.066171 -0.196735
# normalized-losses -0.225016    -0.181877  0.133999      0.238567 -0.101546
# wheel-base        -0.470606    -0.543304  0.584642      0.476153  0.307237
# length            -0.665192    -0.698142  0.690628      0.657373  0.211187
# width             -0.633531    -0.680635  0.751265      0.673363  0.244356
# height            -0.049800    -0.104812  0.135486      0.003811  0.281578
# curb-weight       -0.749543    -0.794889  0.834415      0.785353  0.221046
# engine-size       -0.650546    -0.679571  0.872335      0.745059  0.070779
# bore              -0.582027    -0.591309  0.543155      0.554610  0.054458
# stroke            -0.034696    -0.035201  0.082310      0.037300  0.241303
# compression-ratio  0.331425     0.268465  0.071107     -0.299372  0.985231
# horsepower        -0.822214    -0.804575  0.809575      0.889488 -0.169053
# peak-rpm          -0.115413    -0.058598 -0.101616      0.115830 -0.475812
# city-mpg           1.000000     0.972044 -0.686571     -0.949713  0.265676
# highway-mpg        0.972044     1.000000 -0.704692     -0.930028  0.198690
# price             -0.686571    -0.704692  1.000000      0.789898  0.110326
# city-L/100km      -0.949713    -0.930028  0.789898      1.000000 -0.241282
# diesel             0.265676     0.198690  0.110326     -0.241282  1.000000
# gas               -0.265676    -0.198690 -0.110326      0.241282 -1.000000
#
#                         gas
# symboling          0.196735
# normalized-losses  0.101546
# wheel-base        -0.307237
# length            -0.211187
# width             -0.244356
# height            -0.281578
# curb-weight       -0.221046
# engine-size       -0.070779
# bore              -0.054458
# stroke            -0.241303
# compression-ratio -0.985231
# horsepower         0.169053
# peak-rpm           0.475812
# city-mpg          -0.265676
# highway-mpg       -0.198690
# price             -0.110326
# city-L/100km       0.241282
# diesel            -1.000000
# gas                1.000000

# %% [markdown]
# <b>Descartando la Causalidad : Prueba de Hipotesis Nula</b>:
#
# <p> Para poder interpretar un coeficiente de correlación, primero hay que descartar que no ha sido elegido al azar, es decir que no haya sido casual (si es o no es estadísticamente significativo) , esto se logra con una prueba de hipotesis :  </p>
# <ul>
#     <li> $H_0$ : No existe correlación ($\rho$=0) </li>
#     <li> $H_1$ : Existe correlación ($\rho$!=0) </li>
#
# </ul>
#
# <ul>
#    <li> p-valor es menor 0.05, esto se acepta H1 y se rechaza H0 </li>
#    <li>p-valor es mayor  0.05, se rechaza H1 y se acepta H0</li>
# </ul>
#
#
# <p> Una correlación estadísticamente significativa quiere decir que en una muestra semejante encontraríamos una correlación entre las dos variables distinta de cero (pero no necesariamente de una magnitud parecida). El límite aceptado para descartar el azar es el 5% y se denomina nivel de confianza o significancia </p>

# %% [markdown]
# <b>p-valor</b>:
# <p> ¿Qué es este p-valor? El p-valor [es el valor de probabilidad] de que la correlación entre estas dos variables sea estadísticamente significativa. Normalmente, elegimos un nivel de significancia de 0.05, lo que significa que estamos 95% seguros de que la correlación entre las variables es significativa. </p>
#
# Por convención, cuando el
# <ul>
#     <li> el p-valor es $ <$ 0.001: decimos que hay pruebas sólidas de que la correlación es significativa. </li>
#     <li> el p-valor es $ <$ 0.05: existe evidencia moderada de que la correlación es significativa. </li>
#     <li> el p-valor es $ <$ 0.1: existe evidencia débil de que la correlación es significativa. </li>
#     <li> el p-valor es $> $ 0.1: no hay evidencia de que la correlación sea significativa. </li>
# </ul>

# %% [markdown]
# <b>Scipy</b>:
#
# La libreria SciPy proporciona muchas rutinas numéricas fáciles de usar y eficientes, como rutinas para integración numérica, interpolación, optimización, álgebra lineal y estadísticas.
#
# https://scipy.org/
#
# Para calcular el coeficientes de Pearson y el p-valor se procedera a utilizar el módulo de "estadísticas" de la libreria "scipy"

# %%
from scipy import stats

# %% [markdown]
# <h3>Wheel-base vs Price</h3>

# %% [markdown]
# Calculamos el coeficiente de correlación de Pearson y p-valor entre 'wheel-base' y 'price'.

# %%
#"""
def mi_func():
    return 4,5

var_a, var_b = mi_func()

print(var_a)
print(var_b)
#"""
# Out:
# 4
# 5

# %%
#
#    stats.pearsonr(VariableEntrada, VariableSalida)
#
pearson_coef, p_value = stats.pearsonr(df['wheel-base'], df['price'])

print("El coeficiente de correlación de Pearson es", round(pearson_coef,3),
      " con un p-valor de ", p_value)
# Out:
# El coeficiente de correlación de Pearson es 0.585  con un p-valor de  8.076488270732887e-20

# %% [markdown]
# <h5> Conclusión: </h5>
# <p> Dado que el p-valor es $ <$ 0.001, la correlación entre la distancia entre ejes (wheel-base) y el precio es estadísticamente significativa, aunque la relación lineal no es extremadamente fuerte (~ 0.585) </p>

# %% [markdown]
# <h3>Horsepower vs Price</h3>

# %% [markdown]
# Calculamos el coeficiente de correlación de Pearson y p-valor entre 'horsepower' y 'price'.

# %%
pearson_coef, p_value = stats.pearsonr(df['horsepower'], df['price'])

print("El coeficiente de correlación de Pearson es", round(pearson_coef,3),
      " con un p-valor de ", p_value)
# Out:
# El coeficiente de correlación de Pearson es 0.81  con un p-valor de  6.36905742825956e-48

# %% [markdown]
# <h5> Conclusión: </h5>
# <p> Dado que el p-valor es $ <$ 0.001, la correlación entre los caballos de fuerza (horsepower) y el precio es estadísticamente significativa y la correlación es ligeramente fuerte (~ 0.81) </p>

# %% [markdown]
# <h3>Length vs Price</h3>

# %% [markdown]
# Calculamos el coeficiente de correlación de Pearson y p-valor entre 'length' y 'price'.

# %%
pearson_coef, p_value = stats.pearsonr(df['length'], df['price'])
print("El coeficiente de correlación de Pearson es", round(pearson_coef,3),
      " con un p-valor de ", p_value)
# Out:
# El coeficiente de correlación de Pearson es 0.691  con un p-valor de  8.016477466158871e-30

# %% [markdown]
# <h5> Conclusión: </h5>
# <p> Dado que el p-valor es $ <$ 0.001, la correlación entre la longitud de auto (length) y el precio es estadísticamente significativa y la relación lineal es moderamente fuerte (~ 0.691) </p>

# %% [markdown]
# <h3>Width vs Price</h3>

# %% [markdown]
# Calculamos el coeficiente de correlación de Pearson y p-valor entre 'width' y 'price'.

# %%
pearson_coef, p_value = stats.pearsonr(df['width'], df['price'])
print("El coeficiente de correlación de Pearson es", round(pearson_coef,3),
      " con un p-valor de ", p_value)
# Out:
# El coeficiente de correlación de Pearson es 0.751  con un p-valor de  9.200335510481442e-38

# %% [markdown]
# <h5> Conclusión: </h5>
# <p> Dado que el p-valor es $ <$ 0.001, la correlación entre el ancho del auto y el precio es estadísticamente significativa y la relación lineal es ligeramente fuerte (~ 0.751) </p>

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <h1>Pregunta 5:</h1>
#
# <p>Calcular la correlación de Pearson y el p-valor entre:
#     <ul>
#     <li> Engine-size vs Price
#     <li> City-mpg vs Price
#     <li> Highway-mpg vs Price
#     <li> Bore vs Price
#     </ul>
# </p>
#
# </div>

# %%
pearson_coef, p_value = stats.pearsonr(df['engine-size'], df['price'])
print("El coeficiente de correlación de Pearson es", round(pearson_coef,3),
      " con un p-valor de ", p_value)
# Out:
# El coeficiente de correlación de Pearson es 0.872  con un p-valor de  9.265491622198793e-64

# %%
pearson_coef, p_value = stats.pearsonr(df['bore'], df['price'])
print("El coeficiente de correlación de Pearson es", round(pearson_coef,3),
      " con un p-valor de ", p_value)
# Out:
# El coeficiente de correlación de Pearson es 0.543  con un p-valor de  8.049189483935319e-17

# %%
## df['highway-mpg']

pearson_coef, p_value = stats.pearsonr(df['highway-mpg'], df['price'])
print("El coeficiente de correlación de Pearson es", round(pearson_coef,3),
      " con un p-valor de ", p_value)  

pearson_coef, p_value = stats.pearsonr(df['highway-mpg'], df['price'])
print("El coeficiente de correlación de Pearson es", round(pearson_coef,3),
      " con un p-valor de ", p_value)
# Out:
# El coeficiente de correlación de Pearson es -0.705  con un p-valor de  1.7495471144476463e-31
# El coeficiente de correlación de Pearson es -0.705  con un p-valor de  1.7495471144476463e-31

# %%
# Missing data
missing_data = df.isnull()
percentage_missing_data = (missing_data.sum()/len(missing_data)*100).sort_values(ascending=False)
percentage_missing_data.head()
# Out:
# stroke               1.990050
# horsepower-binned    0.497512
# symboling            0.000000
# engine-size          0.000000
# diesel               0.000000
# dtype: float64

# %%
#df[['stroke','bore']]

#pearson_coef, p_value = stats.pearsonr(df['stroke'], df['price'])
#print("El coeficiente de correlación de Pearson es", round(pearson_coef,3)," con un p-valor de ", p_value)

# %% [markdown]
# <h2 id="anova">6. ANOVA</h2>

# %% [markdown]
# <h3> ANOVA: Análisis de varianza </h3>
# <p> El análisis de varianza (ANOVA) es un método estadístico utilizado para evaluar si existen diferencias significativas entre las medias de dos o más grupos.
#
# <ul>
#     <li> $H_0$ : No hay diferencias entre las medias de los diferentes grupos </li>
#     <li> $H_1$ :Al menos un par de medias son significativamente distintas la una de la otra</li>
#
# </ul>
#
# <p> ANOVA devuelve dos parámetros: </p>
#
# <p> <b> F-test score </b>: ANOVA asume que las medias de todos los grupos son iguales, calcula cuánto se desvían los medios reales de la suposición, y lo informa como el puntaje de F-test. Una puntuación mayor significa que hay una diferencia mayor entre las medias. </p>
#
# <p> <b> P-valor </b>: el p-valor indica cuán estadísticamente significativo es nuestro valor de puntaje calculado. </p>
#
# <p> Si nuestra variable de precio está fuertemente correlacionada con la variable que estamos analizando, espere que ANOVA devuelva una puntuación considerable en la prueba F y un valor p pequeño. </p>

# %% [markdown]
# <h3>Drive Wheels</h3>

# %% [markdown]
# <p> Dado que ANOVA analiza la diferencia entre  grupos de la misma variable, la función groupby será útil. Debido a que el algoritmo ANOVA promedia los datos automáticamente, no necesitamos tomar el promedio de antemano. </p>
#
# <p> Veamos si diferentes tipos de 'drive-wheels' impactan en el 'price'. </p>

# %%
df['drive-wheels'].unique()
# Out:
# array(['rwd', 'fwd', '4wd'], dtype=object)

# %%
df[df["drive-wheels"] == "rwd"]["price"]
# Out:
# 0      13495.0
# 1      16500.0
# 2      16500.0
# 9      16430.0
# 10     16925.0
#         ...
# 196    16845.0
# 197    19045.0
# 198    21485.0
# 199    22470.0
# 200    22625.0
# Name: price, Length: 75, dtype: float64

# %%
df[df["drive-wheels"] == "fwd"]["price"]
# Out:
# 3      13950.0
# 5      15250.0
# 6      17710.0
# 7      18920.0
# 8      23875.0
#         ...
# 185    11595.0
# 186     9980.0
# 187    13295.0
# 188    13845.0
# 189    12290.0
# Name: price, Length: 118, dtype: float64

# %%
df[df["drive-wheels"] == "4wd"]["price"]
# Out:
# 4      17450.0
# 136     7603.0
# 140     9233.0
# 141    11259.0
# 144     8013.0
# 145    11694.0
# 150     7898.0
# 151     8778.0
# Name: price, dtype: float64

# %%
# ANOVA
f_val, p_val = stats.f_oneway(df[df["drive-wheels"] == "fwd"]["price"], 
                              df[df["drive-wheels"] == "rwd"]["price"], 
                              df[df["drive-wheels"] == "4wd"]["price"])  
 
print( "ANOVA results: F=", f_val, ", p-value =", p_val)
# Out:
# ANOVA results: F= 67.95406500780399 , p-value = 3.3945443577151245e-23

# %% [markdown]
# Con una puntuación de F-test grande que muestra una fuerte correlación y un p-valor cercano a 0, garantiza la significancia de la pruebaestadística. Pero, ¿significa esto que los tres grupos probados están tan correlacionados?

# %% [markdown]
# #### Separado: fwd and rwd

# %%
f_val, p_val = stats.f_oneway(df[df["drive-wheels"] == "fwd"]["price"], 
                              df[df["drive-wheels"] == "rwd"]["price"])  
 
print( "ANOVA results: F=", f_val, ", p-value =", p_val)
# Out:
# ANOVA results: F= 130.5533160959111 , p-value = 2.2355306355677845e-23

# %% [markdown]
# #### Separado: 4wd and rwd

# %%
f_val, p_val = stats.f_oneway(df[df["drive-wheels"] == "4wd"]["price"], 
                              df[df["drive-wheels"] == "rwd"]["price"])  
 
print( "ANOVA results: F=", f_val, ", p-value =", p_val)
# Out:
# ANOVA results: F= 8.580681368924756 , p-value = 0.004411492211225333

# %% [markdown]
# #### Separado: 4wd and fwd

# %%
f_val, p_val = stats.f_oneway(df[df["drive-wheels"] == "4wd"]["price"], 
                              df[df["drive-wheels"] == "fwd"]["price"])  
 
print( "ANOVA results: F=", f_val, ", p-value =", p_val)
# Out:
# ANOVA results: F= 0.665465750252303 , p-value = 0.41620116697845666

# %% [markdown]
# <h3>Conclusion: Importantes Variables</h3>

# %% [markdown]
# <p> Ahora tenemos una mejor idea de cómo se ven nuestros datos y qué variables son importantes para tener en cuenta al predecir el precio del automóvil. Lo hemos reducido a las siguientes variables: </p>
#
# Variables numéricas continuas:
# <ul>
#     <li>Length</li>
#     <li>Width</li>
#     <li>Curb-weight</li>
#     <li>Engine-size</li>
#     <li>Horsepower</li>
#     <li>City-mpg</li>
#     <li>Highway-mpg</li>
#     <li>Wheel-base</li>
#     <li>Bore</li>
# </ul>
#
# Variables categóricas:
# <ul>
#     <li>drive-wheels</li>
# </ul>
