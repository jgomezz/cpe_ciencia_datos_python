# %% [markdown]
# - Modulo 2 : Estadistica y Visualizacion de Datos
# - Sesion : 02
# - Fecha : 08/11/2025

# %%
import pandas as pd
import numpy as np

# %%
listado_docentes = {
    "0001": {
        "nombres": "Ana Maria",
        "apellidos": "Lopez Garcia",
        "edad": 34
    },
    "0002": {
        "nombres": "Juan Carlos",
        "apellidos": "Perez Soto",
        "edad": 45
        }
    }

print(listado_docentes["0002"])
# Out:
# {'nombres': 'Juan Carlos', 'apellidos': 'Perez Soto', 'edad': 45}

# %%
df = pd.DataFrame(listado_docentes)
print(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = pd.DataFrame.from_dict(listado_docentes, orient='index')
#       2 print(df)
#
# NameError: name 'pd' is not defined
