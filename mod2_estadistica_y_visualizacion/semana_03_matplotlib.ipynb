# %% [markdown]
# - Modulo 2 : Estadística y Visualización de Datos
# - Sesion : 03 Matplotlib
# - Fecha : 22/11/2025

# %% [markdown]
# ### Introducción

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(-104, 105, 16)
y = x

plt.title("Función Lineal")
plt.xlabel("x")
plt.ylabel("F(x)")
plt.plot(x,y)
plt.grid()
plt.show()

# print(x)

# %%
x = np.arange(-104, 105, 16)
y = 4*x**2

def graficar(x, y, title):
    plt.title(title)
    plt.xlabel("x")
    plt.ylabel("F(x)")
    plt.plot(x,y)
    plt.grid()
    plt.show()

# Realizar gráfico

graficar(x,y,"Gráfico Parábola")

# %%
x = np.arange(-104, 105, 16)
y = x**2 + 3*x + 5

graficar(x,y, "Ecuación Cuadrática")

# %% [markdown]
# ## Tarea 1
# Realice un gráfico de línea de la función trigonométrica seno, cuyo dominio va de 0 a 2π.

# %% [markdown]
# ## Tarea 2
# Realizar el gráfico de temperatura del viernes 21 de noviembre
# Fuente : https://www.tiempo3.com/south-america/peru/lima?page=past-weather#day=21&month=11

# %%
datos = np.genfromtxt('dataset/temperatura/lima_21112025.csv',delimiter=',',skip_header=1)
horas = datos[:,0]
temperaturas = datos[:,1]

graficar(horas, temperaturas, "Temperatura Lima : 21/11/2025")

# %% [markdown]
# ### Funciones personalizadas

# %%
def func(x):
    modelo  = 1/(1+x**2)
    return modelo

x = np.arange(-100, 100, 1)
y = func(x)

graficar(x,y,"Gráfico")

# %% [markdown]
# ### Subgráficos

# %%
# Defino el rango de las x
x = np.arange(0, 2*np.pi, 0.05)

y1 = np.sin(x)
y2 = np.cos(x)
y3 = np.tan(x)
y4 = 1/np.tan(x)

plt.subplot(2,2,1)
plt.title("Sin")
plt.plot(x,y1)

plt.subplot(2,2,2)
plt.title("Cos")
plt.plot(x,y2)

plt.subplot(2,2,3)
plt.title("Tan")
plt.plot(x,y3)

plt.subplot(2,2,4)
plt.title("Cot")
plt.plot(x,y4)

plt.show()
# Out:
# /var/folders/c7/p02yvsh9697_g6yclqsn8p440000gn/T/ipykernel_96775/2053851528.py:7: RuntimeWarning: divide by zero encountered in divide
#   y4 = 1/np.tan(x)

# %% [markdown]
# ## Tarea 3
# Realice un gráfico de línea de la función trigonométrica seno y coseno en dos gráficos distintos, cuyo dominio va de 0 a 2π, utilizando el método ‘subplot’.

# %% [markdown]
# ## Gráficos de Líneas

# %%
x = np.arange(-10, 10, 0.1)

y1 = x
y2 = 4*x + 20
y3 = 8*x + 10

plt.title("Gráfico de líneas con Python")
plt.plot(x, y1, label ="línea y1")
plt.plot(x, y2, label ="línea y2")
plt.plot(x, y3, label ="línea y3")
plt.legend()

#plt.xlim(-5,5)
plt.savefig("output/fig-01")
plt.show()

# %%
def mi_modelo(x):
    m = 3*pow(x,3) + 5*pow(x,2) + 4*x + 4
    m = np.log10(x) * m
    return m


# Defino el rango de las x
x = np.arange(0, np.pi/2, 0.05)

y1 = np.sin(x)
y2 = np.log10(x)
y3 = mi_modelo(x)

plt.title("Gráfico de líneas 2 con Python")
plt.plot(x, y1, label ="Sin")
plt.plot(x, y2, label ="Log")
plt.plot(x, y3, label ="Mi función")
plt.legend()

#plt.xlim(-5,5)
plt.xlabel("x")
plt.ylabel("y")

plt.savefig("output/fig-02")
plt.show()
# Out:
# /var/folders/c7/p02yvsh9697_g6yclqsn8p440000gn/T/ipykernel_96775/1882770184.py:11: RuntimeWarning: divide by zero encountered in log10
#   y2 = np.log10(x)
# /var/folders/c7/p02yvsh9697_g6yclqsn8p440000gn/T/ipykernel_96775/1882770184.py:3: RuntimeWarning: divide by zero encountered in log10
#   m = np.log10(x) * m

# %% [markdown]
# ## Gráfico de líneas a partir de data frames
#
# Se trabajara con la información del FMI : https://www.imf.org/en/publications/sprolls/world-economic-outlook-databases

# %%
import pandas as pd

nombre_archivo = "dataset/fmi/WEO_Data_2021.csv"
df = pd.read_csv(nombre_archivo, thousands=",", decimal=".", sep=";")
df.rename(columns={"Country":"País"} , inplace=True) 
df.set_index('País', inplace=True)

df.head()
# Out:
#                                                     Units     Scale      2001  \
# País
# Argentina  Purchasing power parity; international dollars  Billions   418.488
# Bolivia    Purchasing power parity; international dollars  Billions    30.071
# Brazil     Purchasing power parity; international dollars  Billions  1640.970
# Chile      Purchasing power parity; international dollars  Billions   183.461
# Colombia   Purchasing power parity; international dollars  Billions   275.822
#
#                2002      2003      2004      2005      2006      2007  \
# País
# Argentina   378.796   420.382   470.169   527.728   587.451   657.570
# Bolivia      31.306    32.752    35.038    37.727    40.733    43.736
# Brazil     1717.830  1769.690  1922.010  2045.340  2190.730  2386.120
# Chile       192.133   203.706   224.257   244.518   267.831   288.534
# Colombia    287.201   303.997   328.830   355.030   390.344   427.839
#
#                2008  ...      2018      2019      2020      2021      2022  \
# País                 ...
# Argentina   697.557  ...  1036.980  1033.460   941.848  1015.010  1063.680
# Bolivia      47.328  ...   100.627   104.694    97.804   105.063   111.954
# Brazil     2556.450  ...  3146.320  3247.680  3153.630  3328.460  3491.090
# Chile       304.637  ...   463.993   477.091   454.668   491.535   521.872
# Colombia    450.480  ...   735.284   772.967   728.767   780.262   826.784
#
#                2023      2024      2025      2026  Estimates Start After
# País
# Argentina  1110.140  1152.780  1194.640  1235.730                   2019
# Bolivia     118.836   125.813   132.776   139.866                   2019
# Brazil     3646.490  3797.840  3950.520  4105.750                   2020
# Chile       548.000   573.430   599.070   625.869                   2020
# Colombia    878.906   931.806   986.653  1041.810                   2020
#
# [5 rows x 29 columns]

# %%
anhos = list(map(str, range(2001, 2027)))
#anhos

# %%
info_peru = df.loc["Peru", anhos]
info_peru.plot()
plt.title("PPP Perú : 2021-2026")
plt.xlabel("Años")
plt.ylabel("Mil Millones $")
plt.grid()
plt.show()

# %%
info_peru = df.loc["Peru", anhos]
info_peru.plot(kind = "line")
plt.title("PPP Perú : 2021-2026")
plt.xlabel("Años")
plt.ylabel("Mil Millones $")
plt.text(7,250, '2008 Crisis')
plt.text(23,550, 'Estamos acá')
plt.grid()
plt.savefig("output/fig-03")
plt.show()

# %%
# Grafica de varios paises
paises = df.loc[['Peru','Chile','Colombia'], anhos]
paises = paises.T # Transpuesta de una matriz
paises.plot()
plt.show()

# %%
# Top 5
#df.head()
df.sort_values(by='2025', ascending=False, axis=0 , inplace=True)
df_top5 = df[anhos].head(5).T
df_top5.plot()
plt.show()

# %% [markdown]
# ## Gráficos de áreas

# %%
# Top 5
#df.head()
df.sort_values(by='2025', ascending=False, axis=0 , inplace=True)
df_top5 = df[anhos].head(5).T
df_top5.plot(kind="area", stacked=False)
plt.show()

# %%
# Top 5
#df.head()
df.sort_values(by='2025', ascending=False, axis=0 , inplace=True)
df_top5 = df[anhos].head(5).T
df_top5.plot(kind="area", alpha=0.25, stacked=False)
plt.show()

# %%
# Top 5
#df.head()
df.sort_values(by='2025', ascending=False, axis=0 , inplace=True)
df_top5 = df[anhos].head(5).T
df_top5.plot(kind="area", alpha=0.35, stacked=False)
plt.show()

# %% [markdown]
# ## Tarea 5
# A partir del archivo ‘WEO_Data_Latinoamerica_2022.csv’, realice un gráfico de áreas del PBI del año 2001 al 2006 de los siguientes países: Brasil, México, Argentina, Colombia, Chile y Perú.

# %% [markdown]
# ## Gráficos de Barras

# %%
import pandas as pd

nombre_archivo = "dataset/fmi/dataset_2025-11-22T23_33_05.997052849Z_DEFAULT_INTEGRATION_IMF.RES_WEO_9.0.0.csv"
df = pd.read_csv(nombre_archivo, thousands=",", decimal=".", sep=",")
df.set_index('COUNTRY', inplace=True)
df.head(2)
# Out:
#                       DATASET  SERIES_CODE OBS_MEASURE  \
# COUNTRY
# Argentina  IMF.RES:WEO(9.0.0)  ARG.NGDPD.A   OBS_VALUE
# Colombia   IMF.RES:WEO(9.0.0)  COL.NGDPD.A   OBS_VALUE
#
#                                                    INDICATOR FREQUENCY  \
# COUNTRY
# Argentina  Gross domestic product (GDP), Current prices, ...    Annual
# Colombia   Gross domestic product (GDP), Current prices, ...    Annual
#
#               SCALE     2010     2011     2012     2013  ...     2021  \
# COUNTRY                                                  ...
# Argentina  Billions  424.729  527.644  579.666  611.471  ...  486.040
# Colombia   Billions  286.499  334.966  370.691  382.094  ...  318.525
#
#               2022     2023     2024     2025     2026     2027    2028  \
# COUNTRY
# Argentina  633.520  648.895  637.234  683.371  667.922  710.438  754.27
# Colombia   345.632  366.292  418.818  438.121  462.251  482.176  504.35
#
#               2029     2030
# COUNTRY
# Argentina  798.651  842.591
# Colombia   528.479  552.724
#
# [2 rows x 27 columns]

# %%
anhos = list(map(str, range(2010, 2030)))

info_peru = df.loc["Peru", anhos]
info_peru.plot(kind="bar")
plt.title("GDP Perú : 2010-2029")
plt.xlabel("Años")
plt.ylabel("Miles de Millones $")
plt.grid()
plt.show()

# %%
df.sort_values(by='2025', ascending=True, axis=0 , inplace=True)
df_top = df["2025"].tail(10)
df_top.plot(kind="barh")
plt.xlim(0,2500)

for index, value in enumerate(df_top):
    if not np.isnan(value):
        label = format(int(value), ',')
        plt.annotate(label, xy=(value,index-0.1))

plt.show()
