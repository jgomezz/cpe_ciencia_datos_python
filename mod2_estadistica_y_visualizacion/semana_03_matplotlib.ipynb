# %% [markdown]
# - Modulo 2 : Estadística y Visualización de Datos
# - Sesion : 03 Matplotlib
# - Fecha : 22/11/2025
# - Fecha Actualización : 08/05/2026

# %% [markdown]
# ### Introducción

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(-104, 105, 16)
y = x

plt.title("Función Lineal")
plt.xlabel("x")
plt.ylabel("F(x)")
plt.plot(x,y)
plt.grid()
plt.show()

# print(x)

# %%
x = np.arange(-104, 105, 16)
y = 4*x**2

def graficar(x, y, title):
    plt.title(title)
    plt.xlabel("x")
    plt.ylabel("F(x)")
    plt.plot(x,y)
    plt.grid()
    plt.show()

# Realizar gráfico

graficar(x,y,"Gráfico Parábola")

# %%
x = np.arange(-104, 105, 16)
y = x**2 + 3*x + 5

graficar(x,y, "Ecuación Cuadrática")

# %% [markdown]
# ## Tarea 1
# Realice un gráfico de línea de la función trigonométrica seno, cuyo dominio va de 0 a 2π.

# %%
def grafica_funcion(x,y,titulo,label_x,label_y):
    plt.title(titulo)
    plt.xlabel(label_x)
    plt.ylabel(label_y)
    plt.plot(x,y)
    plt.grid()
    plt.show()

x = np.arange(0, 2*np.pi, 0.05)
y = np.sin(x)

grafica_funcion(x,y,"Función seno","x","F(x)")

# %%
x = np.arange(0, 2*np.pi, 0.1)
y = np.sin(x)

graficar(x, y, "Función Seno")

# %%
x = np.arange(0, 2 * np.pi, 0.1)

y = np.sin(x)

plt.plot(x, y)
plt.show()

# %% [markdown]
# ## Tarea 2
# Realizar el gráfico de temperatura del viernes 21 de noviembre
# Fuente : https://www.tiempo3.com/south-america/peru/lima?page=past-weather#day=21&month=11

# %%
datos = np.genfromtxt('dataset/temperatura/lima_21112025.csv',delimiter=',')
horas = datos[:,0]
temperaturas = datos[:,1]

grafica_funcion(horas, temperaturas, "Temperatura Lima : 21-11-2025","Tiempo (horas)","Temperatura (°C)")

# %% [markdown]
# ### Funciones personalizadas
#
# $$ f(x) = \frac{1}{1 + x^2} $$

# %%
def func(x):
    modelo  = 1/(1+x**2)
    return modelo

x = np.arange(-100, 100, 1)
y = func(x)

graficar(x,y,"Gráfico")

# %% [markdown]
# ### Subgráficos

# %%
# Defino el rango de las x
x = np.arange(0, 2*np.pi, 0.05)

y1 = np.sin(x)
y2 = np.cos(x)
y3 = np.tan(x)
y4 = 1/np.tan(x)

plt.subplot(2,2,1)
plt.title("Sin")
plt.plot(x,y1)

plt.subplot(2,2,2)
plt.title("Cos")
plt.plot(x,y2)

plt.subplot(2,2,3)
plt.title("Tan")
plt.plot(x,y3)

plt.subplot(2,2,4)
plt.title("Cot")
plt.plot(x,y4)

plt.show()
# Out:
# /var/folders/c7/p02yvsh9697_g6yclqsn8p440000gn/T/ipykernel_15060/2053851528.py:7: RuntimeWarning: divide by zero encountered in divide
#   y4 = 1/np.tan(x)

# %% [markdown]
# ## Tarea 3
# Realice un gráfico de línea de la función trigonométrica seno y coseno en dos gráficos distintos, cuyo dominio va de 0 a 2π, utilizando el método ‘subplot’.

# %%
x = np.arange(0, 2*np.pi, 0.05)

y1 = np.sin(x)
y2 = np.cos(x)

plt.subplot(1,2,1)
plt.title("Sin")
plt.plot(x,y1)
plt.grid()

plt.subplot(1,2,2)
plt.title("Cos")
plt.plot(x,y2)
plt.grid()

# %%
import pandas as pd
import matplotlib.pyplot as plt

x = np.arange(0, 2*np.pi, 0.1)
y1 = np.sin(x)
y2 = np.cos(x)

plt.subplot(1,2,1)
plt.title("Función Seno")
plt.plot(x,y1)

plt.subplot(1,2,2)
plt.title("Función Coseno")
plt.plot(x,y2)

plt.show()

# %%
x = np.arange(0, 2*np.pi, 0.05)
y = np.sin(x)
y1 = np.cos(x)

plt.subplot(1,2,1)
plt.title("Seno")
plt.plot(x,y)
plt.grid()
plt.subplot(1,2,2)
plt.title("Coseno")
plt.plot(x,y1)
plt.grid()

# %% [markdown]
# ## Gráficos de Líneas

# %%
x = np.arange(-10, 10, 0.1)

y1 = x
y2 = 4*x + 20
y3 = 8*x + 10

plt.title("Gráfico de líneas con Python")
plt.plot(x, y1, label ="línea y1")
plt.plot(x, y2, label ="línea y2")
plt.plot(x, y3, label ="línea y3")
plt.legend()

#plt.xlim(-5,5)
plt.savefig("output/fig-01")
plt.show()

# %%
def mi_modelo(x):
    m = 3*pow(x,3) + 5*pow(x,2) + 4*x + 4
    m = np.log10(x) * m
    return m


# Defino el rango de las x
x = np.arange(0, np.pi/2, 0.05)

y1 = np.sin(x)
y2 = np.log10(x)
y3 = mi_modelo(x)

plt.title("Gráfico de líneas 2 con Python")
plt.plot(x, y1, label ="Sin")
plt.plot(x, y2, label ="Log")
plt.plot(x, y3, label ="Mi función")
plt.legend()

#plt.xlim(-5,5)
plt.xlabel("x")
plt.ylabel("y")

plt.savefig("output/fig-02")
plt.show()
# Out:
# /var/folders/c7/p02yvsh9697_g6yclqsn8p440000gn/T/ipykernel_15060/1882770184.py:11: RuntimeWarning: divide by zero encountered in log10
#   y2 = np.log10(x)
# /var/folders/c7/p02yvsh9697_g6yclqsn8p440000gn/T/ipykernel_15060/1882770184.py:3: RuntimeWarning: divide by zero encountered in log10
#   m = np.log10(x) * m

# %% [markdown]
# ## Gráfico de líneas a partir de data frames
#
# Se trabajara con la información del FMI : https://www.imf.org/en/publications/sprolls/world-economic-outlook-databases

# %%
import pandas as pd

nombre_archivo = "dataset/fmi/WEO_Data_Latinoamerica_2022.csv"
#df = pd.read_csv(nombre_archivo, thousands=",", decimal=".", sep=";")
df = pd.read_csv(nombre_archivo,  sep=",")
df.rename(columns={"Country":"País"} , inplace=True) 
df.set_index('País', inplace=True)

df.head()
# Out:
#               2000     2001     2002     2003     2004     2005      2006  \
# País
# Argentina  317.759  300.421  112.458  142.431  164.911  199.273   232.892
# Bolivia      8.385    8.155    7.917    8.092    8.785    9.573    11.520
# Brazil     655.454  559.982  509.798  558.232  669.290  891.633  1107.630
# Chile       80.604   73.268   71.835   77.757  101.576  125.439   157.521
# Colombia    99.230   97.566   97.313   94.034  116.336  145.601   161.793
#
#                2007      2008      2009  ...      2019      2020      2021  \
# País                                     ...
# Argentina   287.921   363.545   334.633  ...   451.815   389.064   488.605
# Bolivia      13.216    16.792    17.464  ...    41.193    36.897    39.756
# Brazil     1397.110  1695.860  1669.200  ...  1873.290  1448.550  1608.080
# Chile       176.357   182.574   175.203  ...   278.435   252.501   316.864
# Colombia    206.230   242.504   232.469  ...   323.055   270.415   314.268
#
# ...

# %%
nombre_archivo = "dataset/fmi/WEO_Data_Latinoamerica_2026.csv"
df = pd.read_csv(nombre_archivo,  sep=",")
df.rename(columns={"COUNTRY":"País"} , inplace=True) 
df.set_index('País', inplace=True)

df.head()
# Out:
#                       DATASET  SERIES_CODE OBS_MEASURE  \
# País
# Argentina  IMF.RES:WEO(9.0.0)  ARG.NGDPD.A   OBS_VALUE
# Bolivia    IMF.RES:WEO(9.0.0)  BOL.NGDPD.A   OBS_VALUE
# Colombia   IMF.RES:WEO(9.0.0)  COL.NGDPD.A   OBS_VALUE
# Brazil     IMF.RES:WEO(9.0.0)  BRA.NGDPD.A   OBS_VALUE
# Ecuador    IMF.RES:WEO(9.0.0)  ECU.NGDPD.A   OBS_VALUE
#
#                                                    INDICATOR FREQUENCY  \
# País
# Argentina  Gross domestic product (GDP), Current prices, ...    Annual
# Bolivia    Gross domestic product (GDP), Current prices, ...    Annual
# Colombia   Gross domestic product (GDP), Current prices, ...    Annual
# Brazil     Gross domestic product (GDP), Current prices, ...    Annual
# Ecuador    Gross domestic product (GDP), Current prices, ...    Annual
#
#               SCALE     2000     2001     2002     2003  ...      2022  \
# País                                                     ...
# ...

# %%
anhos = list(map(str, range(2001, 2027)))
#anhos = list(map(str, range(2000, 2032)))
#anhos

# %%
info_peru = df.loc["Peru", anhos]
info_peru.plot()
plt.title("PBI Perú : 2021-2026")
plt.xlabel("Años")
plt.ylabel("Mil Millones $")
plt.grid()
plt.show()

# %%
info_peru = df.loc["Peru", anhos]
info_peru.plot(kind = "line")
plt.title("PBI Perú : 2021-2026")
plt.xlabel("Años")
plt.ylabel("Mil Millones $")
plt.text(9,140, '2008 Crisis')
plt.text(19,220, 'Pandemia')
plt.text(23,300, 'Estamos acá')
plt.grid()
plt.savefig("output/fig-03")
plt.show()

# %%
# Grafica de varios paises
paises = df.loc[['Peru','Chile','Colombia'], anhos]
paises = paises.T # Transpuesta de una matriz
paises.plot()
plt.show()

# %%
# Top 5
#df.head()
df.sort_values(by='2025', ascending=False, axis=0 , inplace=True)
df_top5 = df[anhos].head(5).T
df_top5.plot()
plt.show()

# %% [markdown]
# ### Ejercicio : Graficar el PBI de los 3 paises que tienes menor PBI para el año 2023.
# - A partir del año 2024, no hay información del PBI de Venezuela

# %%
df.sort_values(by='2023', ascending=False, axis=0 , inplace=True)
df_menores3 = df[anhos].tail(3).T
df_menores3.plot()
plt.show()

# %%
df.sort_values(by='2023', ascending=True, axis = 0, inplace=True)
df_menor3 = df[anhos].head(3).T
df_menor3.plot()
plt.title("3 paises con menor PBI en 2025")
plt.xlabel("Años")
plt.ylabel("Mil Millones $")
plt.grid()
plt.show()

# %%
anhos = [str(year) for year in range(2000, 2028)]

df_menores = df[anhos].head(3).T

df_menores.plot(kind='line', figsize=(10, 5), marker='o')

plt.title('Los 3 Países de LATAM con menor PBI (Proyección 2025)')
plt.ylabel('PBI (Miles de Millones USD)')
plt.xlabel('Años')
plt.legend(title='País')

plt.tight_layout()

plt.show()

# %%
#df.head()
df.sort_values(by='2023', ascending=True, axis=0, inplace=True)
df_menor3 = df[anhos].head(3).T
df_menor3.plot()
plt.title("3 países con menor PBI")
plt.xlabel("Año")
plt.ylabel("PBI")
plt.grid(True)

plt.show()

# %% [markdown]
# ## Gráficos de áreas

# %%
# Top 5
#df.head()
df.sort_values(by='2023', ascending=False, axis=0 , inplace=True)
df_top5 = df[anhos].head(5).T
df_top5.plot(kind="area", stacked=False)
plt.show()

# %%
# Top 5
#df.head()
df.sort_values(by='2023', ascending=False, axis=0 , inplace=True)
df_top5 = df[anhos].head(5).T
df_top5.plot(kind="area", alpha=0.25, stacked=False)
plt.show()

# %%
# Top 5
#df.head()
df.sort_values(by='2023', ascending=False, axis=0 , inplace=True)
df_top5 = df[anhos].head(5).T
df_top5.plot(kind="area", alpha=0.35, stacked=False)
plt.show()

# %% [markdown]
# ## Tarea 5
# A partir del archivo ‘WEO_Data_Latinoamerica_2022.csv’, realice un gráfico de áreas del PBI del año 2001 al 2006 de los siguientes países: Brasil, México, Argentina, Colombia, Chile y Perú.

# %%
anhos_2 = list(map(str, range(2001, 2007)))

paises = df.loc[['Brazil','Mexico','Argentina','Colombia','Chile','Peru'], anhos_2]
paises = paises.T 
paises.plot(kind="area", alpha=0.25, stacked=False)
plt.show()

# %%
anhos = [str(year) for year in range(2001, 2007)]

paises = ['Brazil', 'Mexico', 'Argentina', 'Colombia', 'Chile', 'Peru']

df_tarea5 = df.loc[paises, anhos].T

df_tarea5.plot(kind='area', stacked=False, alpha=0.4, figsize=(10, 6))

plt.title('PBI en Latinoamérica (2001-2006)')
plt.ylabel('PBI (Miles de Millones USD)')
plt.xlabel('Años')
plt.grid(True)


plt.legend(title='País', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.show()

# %%
import matplotlib.pyplot as plt

anhos = list(map(str, range(2001, 2007)))

paises = ["Brazil", "Mexico", "Argentina", "Colombia", "Chile", "Peru"]

df_area = df.loc[paises, anhos].T

df_area.plot(kind="area", alpha=0.25, stacked=False)

plt.title("PBI de países latinoamericanos: 2001-2006")
plt.xlabel("Años")
plt.ylabel("Mil Millones $")
plt.grid()
plt.show()

# %% [markdown]
# ## Gráficos de Barras

# %%
import pandas as pd

nombre_archivo = "dataset/fmi/WEO_Data_Latinoamerica_2025.csv"
df = pd.read_csv(nombre_archivo, thousands=",", decimal=".", sep=",")
df.set_index('COUNTRY', inplace=True)
df.head(2)
# Out:
#                       DATASET  SERIES_CODE OBS_MEASURE  \
# COUNTRY
# Argentina  IMF.RES:WEO(9.0.0)  ARG.NGDPD.A   OBS_VALUE
# Colombia   IMF.RES:WEO(9.0.0)  COL.NGDPD.A   OBS_VALUE
#
#                                                    INDICATOR FREQUENCY  \
# COUNTRY
# Argentina  Gross domestic product (GDP), Current prices, ...    Annual
# Colombia   Gross domestic product (GDP), Current prices, ...    Annual
#
#               SCALE     2010     2011     2012     2013  ...     2021  \
# COUNTRY                                                  ...
# Argentina  Billions  424.729  527.644  579.666  611.471  ...  486.040
# Colombia   Billions  286.499  334.966  370.691  382.094  ...  318.525
#
#               2022     2023     2024     2025     2026     2027    2028  \
# COUNTRY
# Argentina  633.520  648.895  637.234  683.371  667.922  710.438  754.27
# Colombia   345.632  366.292  418.818  438.121  462.251  482.176  504.35
#
#               2029     2030
# COUNTRY
# ...

# %%
anhos = list(map(str, range(2010, 2030)))

info_peru = df.loc["Peru", anhos]
info_peru.plot(kind="bar")
plt.title("PBI Perú : 2010-2029")
plt.xlabel("Años")
plt.ylabel("Miles de Millones $")
plt.grid()
plt.show()

# %%
df.sort_values(by='2025', ascending=True, axis=0 , inplace=True)
df_top = df["2025"].tail(10)
df_top.plot(kind="barh")
plt.xlim(0,2500)

for index, value in enumerate(df_top):
    if not np.isnan(value):
        label = format(int(value), ',')
        plt.annotate(label, xy=(value,index-0.1))

plt.show()

# %% [markdown]
# ## Histogramas

# %%
df.head(11)["2025"]
# Out:
# COUNTRY
# Paraguay                                 47.398
# Bolivia                                  57.086
# Venezuela, República Bolivariana de      82.767
# Uruguay                                  84.986
# Ecuador                                 130.529
# Peru                                    318.480
# Chile                                   347.174
# Colombia                                438.121
# Argentina                               683.371
# Mexico                                 1862.740
# Brazil                                 2256.910
# Name: 2025, dtype: float64

# %%
np.histogram(df['2025'])
# Out:
# (array([5, 3, 1, 0, 0, 0, 0, 0, 1, 1]),
#  array([  47.398 ,  268.3492,  489.3004,  710.2516,  931.2028, 1152.154 ,
#         1373.1052, 1594.0564, 1815.0076, 2035.9588, 2256.91  ]))

# %%
# count, bin_edges = np.histogram(df['2025'], bins=8)
df['2025'].plot(kind="hist", bins=10)
plt.show()

# %%
df["2020-2025"] = df["2020"] +  df["2021"] + df["2022"] + df["2023"] + df["2024"] +  df["2025"]

df["2020-2025"].plot.hist(bins=10)
plt.show()

# %% [markdown]
# ### Tarea 6
#
# A partir del archivo WEO_Data_Latinoamerica_2025.csv, grafique un histograma del número de países, cuyo PBI sea mayor a los 250 000 millones de dólares en el año 2025.

# %%
df = pd.read_csv("dataset/fmi/WEO_Data_Latinoamerica_2025.csv")

pbi_2025 = df["2025"]

mayores_250k = pbi_2025[pbi_2025 > 250]

# Mostrar cantidad de países
print("Número de países:", len(mayores_250k))

#Histograma
mayores_250k.plot(kind="hist", bins=10)
plt.title("Países con PBI mayor a 250 000 millones (2025)")
plt.xlabel("PBI (millones de dólares)")
plt.ylabel("Número de países")
plt.show()
# Out:
# Número de países: 6

# %%
import pandas as pd
import matplotlib.pyplot as plt

PBI_altos = df[df['2025'] > 250]['2025']
plt.hist(PBI_altos, bins=5, color='skyblue')

plt.title('Distribución de países con PBI > 250k millones')
plt.xlabel('Rango de PBI 2025')
plt.ylabel('Número de Países')
plt.show()

# %%
import matplotlib.pyplot as plt

nombre_archivo = "dataset/fmi/WEO_Data_Latinoamerica_2025.csv"
df = pd.read_csv(nombre_archivo, thousands=",", decimal=".", sep=",")
df.set_index("COUNTRY", inplace = True)
condicion = df["2025"] > 250
pbi_mayor_250 = df.loc[condicion, "2025"]
pbi_mayor_250.plot.hist(bins=10)
plt.title("Histograma de países con PBI mayor a 250 mil millones en 2025")
plt.xlabel("PBI 2025 - Mil millones de dólares")
plt.ylabel("Número de países")
plt.grid()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('dataset/fmi/WEO_Data_Latinoamerica_2025.csv', encoding='latin1')
paises_objetivo = df[df['2025'] > 250].copy()
plt.figure(figsize=(10, 6))
plt.hist(paises_objetivo['2025'])
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('dataset/fmi/WEO_Data_Latinoamerica_2025.csv')

df_filtrado = df[df['2025'] > 250]
plt.figure(figsize=(10, 6))
df_filtrado['2025'].plot.hist()
plt.title('Histograma del PBI (Año 2025 > 250,000 millones)', fontsize=14)

# %% [markdown]
# ## Gráfico de Cajas : Box Plot

# %%
import pandas as pd

df = pd.read_csv("dataset/panamericanos/medallero_Panamericanos_Lima2019.csv")

df.head(10)
# Out:
#    Posicion                  Pais  Oro  Plata  Bronce  Total  RankingTotal  \
# 0         1        Estados Unidos  120     88      85    293             1
# 1         2                Brasil   55     45      71    171             2
# 2         3                México   37     36      63    136             4
# 3         4                Canadá   35     64      53    152             3
# 4         5                  Cuba   33     27      38     98             6
# 5         6             Argentina   32     35      34    101             5
# 6         7              Colombia   28     23      33     84             7
# 7         8                 Chile   13     19      18     50             8
# 8         9                  Perú   11      7      21     39            11
# 9        10  República Dominicana   10     13      17     40            10
#
#                  Zona
# 0   America del Norte
# 1     America del Sur
# 2   America del Norte
# 3   America del Norte
# 4  America del Centro
# ...

# %%
df_top_20 = df.head(20)

df_top_20[["Oro","Plata","Bronce"]].plot.box()
plt.show()

# %%
df = pd.read_csv("dataset/panamericanos/medallero_Panamericanos_Santiago2023.csv")
df_top_20 = df.head(20)

df_top_20[["Oro","Plata","Bronce"]].plot.box()
plt.show()
