# %% [markdown]
# # Práctica de aula 1

# %% [markdown]
# ### Pregunta 2

# %%
import numpy as np
nro_list = [[1.1, 2.3, 3.1], [4.2, 5.8, 8.3]]
nro_array = np.array(nro_list)
print(nro_array.shape)
# Out:
# (2, 3)

# %% [markdown]
# ### Pregunta 3

# %%
import numpy as np
a_array = np.arange(1, 8)
print(a_array.max() - a_array.min())
# Out:
# 6

# %% [markdown]
# ### Pregunta 4

# %%
import numpy as np
a_array = np.arange(0, 9, 2)
print(a_array[0:5])
# Out:
# [0 2 4 6 8]

# %% [markdown]
# ### Pregunta 5

# %%
import numpy as np
d1 = np.ones((1, 3))
d2 = np.zeros((1, 3))
print(np.hstack((d2, d1)))
# Out:
# [[0. 0. 0. 1. 1. 1.]]

# %% [markdown]
# ### Pregunta 6

# %%
import numpy as np
a_matrix = np.arange(0, 16).reshape(4, 4)
a_matrix.var()
# Out:
# 21.25

# %% [markdown]
# ### Pregunta 7

# %%
import pandas as pd
data_dic = {"Pais": ["Peru", "Bolivia", "Chile", "Ecuador", "Argentina"],
            "Oro": [11, 9, 7, 7, 11],
            "Plata": [22, 20, 13, 15, 13]}
df = pd.DataFrame(data_dic)
print(df['Oro'].mode())
# Out:
# 0     7
# 1    11
# Name: Oro, dtype: int64

# %% [markdown]
# ### Pregunta 8

# %%
import pandas as pd
data_dic = {"Pais": ["Perú", "Chile", "Ecuador"],
            "Oro": [11, 9, 7],
            "Plata": [22, 20, 10]}
df = pd.DataFrame(data_dic)
print(df['Plata'].sum())
# Out:
# 52

# %% [markdown]
# ### Pregunta 9

# %%
import pandas as pd
data_dic = {"Pais": ["Perú", "Chile", "Ecuador", "Bolivia"],
                     "Oro": [11, 9, 8, 4],
                     "Plata": [22, 20, 10, 5]}
df = pd.DataFrame(data_dic)
print(df['Oro'].mean())
# Out:
# 8.0

# %% [markdown]
# ### Pregunta 10

# %%
import pandas as pd
data_dic = {"Pais": ["Perú","Chile","Ecuador","Bolivia"],
                     "Oro": [11, 9, 8, 4],
                     "Plata": [22, 20, 10, 5]}
df = pd.DataFrame(data_dic)
print(df['Plata'].median())
# Out:
# 15.0
